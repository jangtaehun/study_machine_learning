# %%
import xgboost as xgb
from xgboost import plot_importance

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test, pred)
    
    accuracy = accuracy_score(y_test , pred)
    
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    
    f1 = f1_score(y_test,pred)
    
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba)
    
    print('오차 행렬')
    print(confusion)
    
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

def precision_recall_curve_plot(y_test=None, pred_proba_c1=None):
    
    # threshold ndarray와 이 threshold에 따른 정밀도, 재현율 ndarray 추출. 
    precisions, recalls, thresholds = precision_recall_curve( y_test, pred_proba_c1)
    
    # X축을 threshold값으로, Y축은 정밀도, 재현율 값으로 각각 Plot 수행. 정밀도는 점선으로 표시
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    # threshold 값 X 축의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    # x축, y축 label과 legend, 그리고 grid 설정
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend(); plt.grid()
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pd.read_csv('./titanic/titanic_train.csv')
predict_df = pd.read_csv('./titanic/test.csv')
gender_submission_df = pd.read_csv('./titanic/gender_submission.csv')

# 알파벳 뒤에 붙는 숫자 값은 무시하고 Alphabet만 가져오는 전략을 선택
train_df['Cabin'] = train_df['Cabin'].str[:1]

def get_category_age(age):
    cat = ''
    if age <= -1: cat = 0
    elif age <= 5: cat = 1
    elif age <= 12: cat = 2
    elif age <= 18: cat = 3
    elif age <= 25: cat = 4
    elif age <= 35: cat = 5
    elif age <= 60: cat = 6
    else: cat = 7
               
    return cat

group_names = [0, 1, 2, 3, 4, 5, 6, 7]
train_df['Age_range'] = train_df['Age'].apply(lambda x : get_category_age(x))

def get_category_fare(fare):
    cat = ''
    if fare <= 0: cat = 0
    elif fare <= 10: cat = 1
    elif fare <= 20: cat = 2
    elif fare <= 30: cat = 3
    elif fare <= 40: cat = 4
    elif fare <= 50: cat = 5
    elif fare <= 60: cat = 6
    else: cat = 7
               
    return cat

group_names = [0, 1, 2, 3, 4, 5, 6, 7]
train_df['Fare_range'] = train_df['Fare'].apply(lambda x : get_category_fare(x))

# 불필요한 특성, null 값 제거
def drop_features(df):
    df.drop(['PassengerId','Name','Ticket', 'Age', 'Fare'], axis=1, inplace=True)

    y = df['Survived']
    df = df.drop('Survived', axis=1, inplace=False)
    return df, y

def fillna(df):
    df['Cabin'] = df['Cabin'].fillna('N')
    df['Embarked'] = df['Embarked'].fillna('N')
    return df
# predict_df에서 사용
def drop_features_update(df):
    df.drop(['PassengerId','Name','Ticket', 'Age', 'Fare'], axis=1, inplace=True)
    return df

train_df = fillna(train_df)
X, y = drop_features(train_df)


# 라벨 인코딩 구현
# Sex
def get_category_sex(sex):
    cat = ''
    if sex == "male": cat = 0
    else: cat = 1
    return cat

group_names = [0, 1]
X['Sex'] = X['Sex'].apply(lambda x : get_category_sex(x))

# Embarked
def get_category_embarked(embarked):
    cat = ''
    if embarked == "S": cat = 0
    elif embarked == "C": cat= 1
    elif embarked == "Q": cat= 2
    else: cat = 3
    return cat

group_names = [0, 1, 2, 3]
X['Embarked'] = X['Embarked'].apply(lambda x : get_category_embarked(x))

# Cabin
def get_category_cabin(cabin):
    cat = ''
    if cabin == "A": cat = 0
    elif cabin == "B": cat= 1
    elif cabin == "C": cat= 2
    elif cabin == "D": cat= 3
    elif cabin == "E": cat= 4
    elif cabin == "F": cat= 5
    elif cabin == "G": cat= 6
    elif cabin == "N": cat= 7
    else: cat = 8
    return cat

group_names = [0, 1, 2, 3, 4, 5, 6, 7, 8]
X['Cabin'] = X['Cabin'].apply(lambda x : get_category_cabin(x))

print(X.head())

from sklearn.preprocessing import StandardScaler

# # 표준화 => 2차원 데이터
# sc = StandardScaler()
# X = sc.fit_transform(X)
# X[1]
# Out:
#    Pclass  Sex  SibSp  Parch  Cabin  Embarked  Age_range  Fare_range
# 0       3    0      1      0      7         0          4           1
# 1       1    1      1      0      2         1          6           7
# 2       3    1      0      0      7         0          5           1
# 3       1    1      1      0      2         0          5           6
# 4       3    0      0      0      7         0          5           1

# %%
predict_df['Age_range'] = predict_df['Age'].apply(lambda x : get_category_age(x))

predict_df['Fare_range'] = predict_df['Fare'].apply(lambda x : get_category_fare(x))

predict_df = fillna(predict_df)
predict_df = drop_features_update(predict_df)

predict_df['Sex'] = predict_df['Sex'].apply(lambda x : get_category_sex(x))
predict_df['Embarked'] = predict_df['Embarked'].apply(lambda x : get_category_embarked(x))

predict_df['Cabin'] = predict_df['Cabin'].str[:1]
predict_df['Cabin'] = predict_df['Cabin'].apply(lambda x : get_category_cabin(x))

print(predict_df.head(3))

# predict_df = sc.transform(predict_df)
# predict_df[1]
# Out:
#    Pclass  Sex  SibSp  Parch  Cabin  Embarked  Age_range  Fare_range
# 0       3    0      0      0      7         2          5           1
# 1       3    1      1      0      7         0          6           1
# 2       2    0      0      0      7         2          7           1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 위에서 만든 X_train, y_train을 다시 쪼개서 90%는 학습과 10%는 검증용 데이터로 분리 
X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=156 )

# %% [markdown]
# > - 뛰어난 성능과 효율성으로 인해 최근 가장 널리 사용되는 강력한 머신러닝 알고리즘 중 하나
# > - XGBoost는 gradient boosting 알고리즘을 확장한 것입니다. 이는 약한 학습기(weak learner)들을 순차적으로 학습시켜 강한 예측기(strong predictor)를 만드는 ensemble 방식
# > - 성능향상
# > - 병렬 처리: 트리 구축 과정을 병렬화하여 학습 속도를 높였습니다.
# 정규화: 과적합을 방지하기 위해 L1, L2 정규화를 적용했습니다.
# 누락값 처리: 누락값을 자동으로 처리할 수 있습니다.
# 가중치 정규화: 트리의 복잡도를 제어하여 과적합을 방지합니다.
#
# > - 장점
# > - 뛰어난 성능: 다양한 문제에서 최고의 성능을 보여줍니다.
# 빠른 학습 속도: 병렳 처리와 최적화된 구현으로 빠른 학습이 가능합니다.
# 다양한 데이터 유형 지원: 숫자형, 범주형, 결측값 등 다양한 데이터를 처리할 수 있습니다.
# 높은 확장성: 대용량 데이터에도 잘 작동합니다.
#
# > - 하이퍼파라미터
# > - max_depth: 개별 트리의 최대 깊이
# n_estimators: 생성할 트리의 개수
# learning_rate: 각 트리의 기여도를 조절하는 학습률
# gamma: 노드 분할에 필요한 최소 손실 감소량
# reg_alpha, reg_lambda: L1, L2 정규화 계수

# %%
# 만약 구버전 XGBoost에서 DataFrame으로 DMatrix 생성이 안될 경우 X_train.values로 넘파이 변환. 
# 학습, 검증, 테스트용 DMatrix를 생성. 
dtr = xgb.DMatrix(data=X_tr, label=y_tr)
dval = xgb.DMatrix(data=X_val, label=y_val)
dtest = xgb.DMatrix(data=X_test , label=y_test)

params = { 'max_depth':3,
           'eta': 0.05, # learning-rate
           'objective':'binary:logistic', #iteration, 목적함수(objective)는 binary:logistic(이진 로지스틱)
           'eval_metric':'logloss'
        }
num_rounds = 400 # n_estermators, 생성할 weak learner의 수


# 학습 데이터 셋은 'train' 또는 평가 데이터 셋은 'eval' 로 명기합니다. 
eval_list = [(dtr,'train'),(dval,'eval')] # 또는 eval_list = [(dval,'eval')] 만 명기해도 무방. 

# 하이퍼 파라미터와 early stopping 파라미터를 train( ) 함수의 파라미터로 전달
xgb_model = xgb.train(params = params , dtrain=dtr , num_boost_round=num_rounds, \
                      early_stopping_rounds=50, evals=eval_list)
# Out:
# [0]	train-logloss:0.65423	eval-logloss:0.57225
# [1]	train-logloss:0.63510	eval-logloss:0.55531
# [2]	train-logloss:0.61775	eval-logloss:0.53974
# [3]	train-logloss:0.60199	eval-logloss:0.52552
# [4]	train-logloss:0.58761	eval-logloss:0.51312
# [5]	train-logloss:0.57446	eval-logloss:0.50100
# [6]	train-logloss:0.56242	eval-logloss:0.48986
# [7]	train-logloss:0.55137	eval-logloss:0.48019
# [8]	train-logloss:0.54121	eval-logloss:0.47065
# [9]	train-logloss:0.53186	eval-logloss:0.46176
# [10]	train-logloss:0.52325	eval-logloss:0.45382
# [11]	train-logloss:0.51529	eval-logloss:0.44619
# [12]	train-logloss:0.50795	eval-logloss:0.43910
# [13]	train-logloss:0.50116	eval-logloss:0.43250
# [14]	train-logloss:0.49487	eval-logloss:0.42659
# [15]	train-logloss:0.48906	eval-logloss:0.42081
# [16]	train-logloss:0.48377	eval-logloss:0.41552
# [17]	train-logloss:0.47875	eval-logloss:0.41071
# [18]	train-logloss:0.47403	eval-logloss:0.40696
# [19]	train-logloss:0.46976	eval-logloss:0.40281
# [20]	train-logloss:0.46563	eval-logloss:0.40023
# [21]	train-logloss:0.46176	eval-logloss:0.39705
# [22]	train-logloss:0.45814	eval-logloss:0.39466
# [23]	train-logloss:0.45473	eval-logloss:0.39184
# [24]	train-logloss:0.45164	eval-logloss:0.38865
# [25]	train-logloss:0.44861	eval-logloss:0.38682
# [26]	train-logloss:0.44587	eval-logloss:0.38517
# [27]	train-logloss:0.44320	eval-logloss:0.38223
# [28]	train-logloss:0.44065	eval-logloss:0.38086
# [29]	train-logloss:0.43843	eval-logloss:0.37952
# [30]	train-logloss:0.43636	eval-logloss:0.37757
# [31]	train-logloss:0.43420	eval-logloss:0.37708
# [32]	train-logloss:0.43227	eval-logloss:0.37594
# [33]	train-logloss:0.43046	eval-logloss:0.37461
# [34]	train-logloss:0.42875	eval-logloss:0.37406
# [35]	train-logloss:0.42713	eval-logloss:0.37371
# [36]	train-logloss:0.42540	eval-logloss:0.37325
# [37]	train-logloss:0.42392	eval-logloss:0.37153
# [38]	train-logloss:0.42251	eval-logloss:0.37169
# [39]	train-logloss:0.42106	eval-logloss:0.37067
# [40]	train-logloss:0.41961	eval-logloss:0.37050
# [41]	train-logloss:0.41838	eval-logloss:0.37076
# [42]	train-logloss:0.41720	eval-logloss:0.36997
# [43]	train-logloss:0.41621	eval-logloss:0.36922
# [44]	train-logloss:0.41502	eval-logloss:0.36892
# [45]	train-logloss:0.41389	eval-logloss:0.36909
# [46]	train-logloss:0.41284	eval-logloss:0.36901
# [47]	train-logloss:0.41176	eval-logloss:0.36862
# [48]	train-logloss:0.41069	eval-logloss:0.36841
# [49]	train-logloss:0.40976	eval-logloss:0.36838
# [50]	train-logloss:0.40877	eval-logloss:0.36784
# [51]	train-logloss:0.40780	eval-logloss:0.36803
# [52]	train-logloss:0.40698	eval-logloss:0.36898
# [53]	train-logloss:0.40608	eval-logloss:0.36809
# [54]	train-logloss:0.40518	eval-logloss:0.36831
# [55]	train-logloss:0.40445	eval-logloss:0.36924
# [56]	train-logloss:0.40362	eval-logloss:0.36793
# [57]	train-logloss:0.40280	eval-logloss:0.36819
# [58]	train-logloss:0.40214	eval-logloss:0.36911
# [59]	train-logloss:0.40138	eval-logloss:0.36882
# [60]	train-logloss:0.40065	eval-logloss:0.36760
# [61]	train-logloss:0.39989	eval-logloss:0.36740
# [62]	train-logloss:0.39922	eval-logloss:0.36715
# [63]	train-logloss:0.39850	eval-logloss:0.36757
# [64]	train-logloss:0.39788	eval-logloss:0.36735
# [65]	train-logloss:0.39736	eval-logloss:0.36827
# [66]	train-logloss:0.39673	eval-logloss:0.36770
# [67]	train-logloss:0.39619	eval-logloss:0.36752
# [68]	train-logloss:0.39555	eval-logloss:0.36798
# [69]	train-logloss:0.39505	eval-logloss:0.36782
# [70]	train-logloss:0.39447	eval-logloss:0.36732
# [71]	train-logloss:0.39389	eval-logloss:0.36831
# [72]	train-logloss:0.39343	eval-logloss:0.36817
# [73]	train-logloss:0.39303	eval-logloss:0.36852
# [74]	train-logloss:0.39250	eval-logloss:0.36805
# [75]	train-logloss:0.39181	eval-logloss:0.36862
# [76]	train-logloss:0.39141	eval-logloss:0.36852
# [77]	train-logloss:0.39092	eval-logloss:0.36810
# [78]	train-logloss:0.39055	eval-logloss:0.36801
# [79]	train-logloss:0.39006	eval-logloss:0.36950
# [80]	train-logloss:0.38971	eval-logloss:0.36917
# [81]	train-logloss:0.38872	eval-logloss:0.37019
# [82]	train-logloss:0.38826	eval-logloss:0.37093
# [83]	train-logloss:0.38796	eval-logloss:0.37118
# [84]	train-logloss:0.38742	eval-logloss:0.37166
# [85]	train-logloss:0.38698	eval-logloss:0.37129
# [86]	train-logloss:0.38668	eval-logloss:0.37123
# [87]	train-logloss:0.38641	eval-logloss:0.37157
# [88]	train-logloss:0.38554	eval-logloss:0.37259
# [89]	train-logloss:0.38505	eval-logloss:0.37238
# [90]	train-logloss:0.38465	eval-logloss:0.37204
# [91]	train-logloss:0.38423	eval-logloss:0.37274
# [92]	train-logloss:0.38344	eval-logloss:0.37378
# [93]	train-logloss:0.38299	eval-logloss:0.37360
# [94]	train-logloss:0.38273	eval-logloss:0.37429
# [95]	train-logloss:0.38231	eval-logloss:0.37482
# [96]	train-logloss:0.38194	eval-logloss:0.37450
# [97]	train-logloss:0.38147	eval-logloss:0.37529
# [98]	train-logloss:0.38125	eval-logloss:0.37556
# [99]	train-logloss:0.38099	eval-logloss:0.37513
# [100]	train-logloss:0.38058	eval-logloss:0.37501
# [101]	train-logloss:0.38026	eval-logloss:0.37487
# [102]	train-logloss:0.37987	eval-logloss:0.37473
# [103]	train-logloss:0.37958	eval-logloss:0.37520
# [104]	train-logloss:0.37929	eval-logloss:0.37508
# [105]	train-logloss:0.37902	eval-logloss:0.37539
# [106]	train-logloss:0.37835	eval-logloss:0.37642
# [107]	train-logloss:0.37798	eval-logloss:0.37657
# [108]	train-logloss:0.37769	eval-logloss:0.37645
# [109]	train-logloss:0.37730	eval-logloss:0.37668
# [110]	train-logloss:0.37699	eval-logloss:0.37646
# [111]	train-logloss:0.37670	eval-logloss:0.37649

# %%
# predict()를 통해 예측 확률값을 반환하고 예측 값으로 변환
pred_probs = xgb_model.predict(dtest)
print('predict( ) 수행 결과값을 10개만 표시, 예측 확률 값으로 표시됨')
print(np.round(pred_probs[:10],3), "\n")

# 예측 확률이 0.5 보다 크면 1, 그렇지 않으면 0 으로 예측값 결정하여 List 객체인 preds에 저장 
preds = [ 1 if x > 0.5 else 0 for x in pred_probs ]
print('예측값 10개만 표시:',preds[:10], "\n")

get_clf_eval(y_test , preds, pred_probs)
print("\n")

fig, ax = plt.subplots(figsize=(10, 5))
plot_importance(xgb_model, ax=ax) # ax가 그림을 그린다.
# Out:
# predict( ) 수행 결과값을 10개만 표시, 예측 확률 값으로 표시됨
# [0.159 0.075 0.067 0.955 0.551 0.155 0.92  0.936 0.402 0.79 ]
#
# 예측값 10개만 표시: [0, 0, 0, 1, 1, 0, 1, 1, 0, 1]
#
# 오차 행렬
# [[97 13]
#  [20 49]]
# 정확도: 0.8156, 정밀도: 0.7903, 재현율: 0.7101,    F1: 0.7481, AUC:0.8889
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
dpredict = xgb.DMatrix(data=predict_df)

predict_titanic_pred_xgb = xgb_model.predict(dpredict)
preds_xgb = [ 1 if x > 0.5 else 0 for x in predict_titanic_pred_xgb]
print(f"predict_titanic_Voting 예측: {predict_titanic_pred_xgb[:10]}")
print('예측값 10개만 표시:',preds_xgb[:10], "\n")

gender_submission_df['Survived'] = preds_xgb
gender_submission_df.to_csv('titanic_submission_xgb.csv',index=False)
gender_submission_df
# Out:
# predict_titanic_Voting 예측: [0.21176656 0.55627114 0.107283   0.19013669 0.3735853  0.13017876
#  0.85130155 0.15791108 0.7982232  0.08893801]
# 예측값 10개만 표시: [0, 1, 0, 0, 0, 0, 1, 0, 1, 0]
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
# 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

# Warning 메시지를 없애기 위해 eval_metric 값을 XGBClassifier 생성 인자로 입력. 미 입력해도 수행에 문제 없음.   
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3, eval_metric='logloss')
xgb_wrapper.fit(X_train, y_train, verbose=True)

w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test , w_preds, w_pred_proba)

fig, ax = plt.subplots(figsize=(10, 5))
plot_importance(xgb_wrapper, ax=ax)
# Out:
# 오차 행렬
# [[101   9]
#  [ 21  48]]
# 정확도: 0.8324, 정밀도: 0.8421, 재현율: 0.6957,    F1: 0.7619, AUC:0.8886
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
predict_titanic_pred_xgb_python = xgb_wrapper.predict(predict_df)
preds_xgb_python = [ 1 if x > 0.5 else 0 for x in predict_titanic_pred_xgb_python]
print(f"predict_titanic_Voting 예측: {predict_titanic_pred_xgb_python[:10]}")
print('예측값 10개만 표시:',preds_xgb_python[:10], "\n")

gender_submission_df['Survived'] = preds_xgb_python
gender_submission_df.to_csv('titanic_submission_xgb_python.csv',index=False)
gender_submission_df
# Out:
# predict_titanic_Voting 예측: [0 0 0 0 0 0 1 0 1 0]
# 예측값 10개만 표시: [0, 0, 0, 0, 0, 0, 1, 0, 1, 0]
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %% [markdown]
# ### early stopping을 50으로 설정하고 재 학습/예측/평가
# > - tr, val 나눠서 실행

# %%
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3)
evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=50, eval_metric="logloss", eval_set=evals, verbose=True)

ws50_preds = xgb_wrapper.predict(X_test)
ws50_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test , ws50_preds, ws50_pred_proba)

fig, ax = plt.subplots(figsize=(10, 5))
plot_importance(xgb_wrapper, ax=ax)
# Out:
# [0]	validation_0-logloss:0.65423	validation_1-logloss:0.57225
# [1]	validation_0-logloss:0.63510	validation_1-logloss:0.55531
# [2]	validation_0-logloss:0.61775	validation_1-logloss:0.53974
# [3]	validation_0-logloss:0.60199	validation_1-logloss:0.52552
# [4]	validation_0-logloss:0.58761	validation_1-logloss:0.51312
# [5]	validation_0-logloss:0.57446	validation_1-logloss:0.50100
# [6]	validation_0-logloss:0.56242	validation_1-logloss:0.48986
# [7]	validation_0-logloss:0.55137	validation_1-logloss:0.48019
# [8]	validation_0-logloss:0.54121	validation_1-logloss:0.47065
# [9]	validation_0-logloss:0.53186	validation_1-logloss:0.46176
# [10]	validation_0-logloss:0.52325	validation_1-logloss:0.45382
# [11]	validation_0-logloss:0.51529	validation_1-logloss:0.44619
# [12]	validation_0-logloss:0.50795	validation_1-logloss:0.43910
# [13]	validation_0-logloss:0.50116	validation_1-logloss:0.43250
# [14]	validation_0-logloss:0.49487	validation_1-logloss:0.42659
# [15]	validation_0-logloss:0.48906	validation_1-logloss:0.42081
# [16]	validation_0-logloss:0.48377	validation_1-logloss:0.41552
# [17]	validation_0-logloss:0.47875	validation_1-logloss:0.41071
# [18]	validation_0-logloss:0.47403	validation_1-logloss:0.40696
# [19]	validation_0-logloss:0.46976	validation_1-logloss:0.40281
# [20]	validation_0-logloss:0.46563	validation_1-logloss:0.40023
# [21]	validation_0-logloss:0.46176	validation_1-logloss:0.39705
# [22]	validation_0-logloss:0.45814	validation_1-logloss:0.39466
# [23]	validation_0-logloss:0.45473	validation_1-logloss:0.39184
# [24]	validation_0-logloss:0.45164	validation_1-logloss:0.38865
# [25]	validation_0-logloss:0.44861	validation_1-logloss:0.38682
# [26]	validation_0-logloss:0.44587	validation_1-logloss:0.38517
# [27]	validation_0-logloss:0.44320	validation_1-logloss:0.38223
# [28]	validation_0-logloss:0.44065	validation_1-logloss:0.38086
# [29]	validation_0-logloss:0.43843	validation_1-logloss:0.37952
# [30]	validation_0-logloss:0.43636	validation_1-logloss:0.37757
# [31]	validation_0-logloss:0.43420	validation_1-logloss:0.37708
# [32]	validation_0-logloss:0.43227	validation_1-logloss:0.37594
# [33]	validation_0-logloss:0.43046	validation_1-logloss:0.37461
# [34]	validation_0-logloss:0.42875	validation_1-logloss:0.37406
# [35]	validation_0-logloss:0.42713	validation_1-logloss:0.37371
# [36]	validation_0-logloss:0.42540	validation_1-logloss:0.37325
# [37]	validation_0-logloss:0.42392	validation_1-logloss:0.37153
# [38]	validation_0-logloss:0.42251	validation_1-logloss:0.37169
# [39]	validation_0-logloss:0.42106	validation_1-logloss:0.37067
# [40]	validation_0-logloss:0.41961	validation_1-logloss:0.37050
# [41]	validation_0-logloss:0.41838	validation_1-logloss:0.37076
# [42]	validation_0-logloss:0.41720	validation_1-logloss:0.36997
# [43]	validation_0-logloss:0.41621	validation_1-logloss:0.36922
# [44]	validation_0-logloss:0.41502	validation_1-logloss:0.36892
# [45]	validation_0-logloss:0.41389	validation_1-logloss:0.36909
# [46]	validation_0-logloss:0.41284	validation_1-logloss:0.36901
# [47]	validation_0-logloss:0.41176	validation_1-logloss:0.36862
# [48]	validation_0-logloss:0.41069	validation_1-logloss:0.36841
# [49]	validation_0-logloss:0.40976	validation_1-logloss:0.36838
# [50]	validation_0-logloss:0.40877	validation_1-logloss:0.36784
# [51]	validation_0-logloss:0.40780	validation_1-logloss:0.36803
# [52]	validation_0-logloss:0.40698	validation_1-logloss:0.36898
# [53]	validation_0-logloss:0.40608	validation_1-logloss:0.36809
# [54]	validation_0-logloss:0.40518	validation_1-logloss:0.36831
# [55]	validation_0-logloss:0.40445	validation_1-logloss:0.36924
# [56]	validation_0-logloss:0.40362	validation_1-logloss:0.36793
# [57]	validation_0-logloss:0.40280	validation_1-logloss:0.36819
# [58]	validation_0-logloss:0.40214	validation_1-logloss:0.36911
# [59]	validation_0-logloss:0.40138	validation_1-logloss:0.36882
# [60]	validation_0-logloss:0.40065	validation_1-logloss:0.36760
# [61]	validation_0-logloss:0.39989	validation_1-logloss:0.36740
# [62]	validation_0-logloss:0.39922	validation_1-logloss:0.36715
# [63]	validation_0-logloss:0.39850	validation_1-logloss:0.36757
# [64]	validation_0-logloss:0.39788	validation_1-logloss:0.36735
# [65]	validation_0-logloss:0.39736	validation_1-logloss:0.36827
# [66]	validation_0-logloss:0.39673	validation_1-logloss:0.36770
# [67]	validation_0-logloss:0.39619	validation_1-logloss:0.36752
# [68]	validation_0-logloss:0.39555	validation_1-logloss:0.36798
# [69]	validation_0-logloss:0.39505	validation_1-logloss:0.36782
# [70]	validation_0-logloss:0.39447	validation_1-logloss:0.36732
# [71]	validation_0-logloss:0.39389	validation_1-logloss:0.36831
# [72]	validation_0-logloss:0.39343	validation_1-logloss:0.36817
# [73]	validation_0-logloss:0.39303	validation_1-logloss:0.36852
# [74]	validation_0-logloss:0.39250	validation_1-logloss:0.36805
# [75]	validation_0-logloss:0.39181	validation_1-logloss:0.36862
# [76]	validation_0-logloss:0.39141	validation_1-logloss:0.36852
# [77]	validation_0-logloss:0.39092	validation_1-logloss:0.36810
# [78]	validation_0-logloss:0.39055	validation_1-logloss:0.36801
# [79]	validation_0-logloss:0.39006	validation_1-logloss:0.36950
# [80]	validation_0-logloss:0.38971	validation_1-logloss:0.36917
# [81]	validation_0-logloss:0.38872	validation_1-logloss:0.37019
# [82]	validation_0-logloss:0.38826	validation_1-logloss:0.37093
# [83]	validation_0-logloss:0.38796	validation_1-logloss:0.37118
# [84]	validation_0-logloss:0.38742	validation_1-logloss:0.37166
# [85]	validation_0-logloss:0.38698	validation_1-logloss:0.37129
# [86]	validation_0-logloss:0.38668	validation_1-logloss:0.37123
# [87]	validation_0-logloss:0.38641	validation_1-logloss:0.37157
# [88]	validation_0-logloss:0.38554	validation_1-logloss:0.37259
# [89]	validation_0-logloss:0.38505	validation_1-logloss:0.37238
# [90]	validation_0-logloss:0.38465	validation_1-logloss:0.37204
# [91]	validation_0-logloss:0.38423	validation_1-logloss:0.37274
# [92]	validation_0-logloss:0.38344	validation_1-logloss:0.37378
# [93]	validation_0-logloss:0.38299	validation_1-logloss:0.37360
# [94]	validation_0-logloss:0.38273	validation_1-logloss:0.37429
# [95]	validation_0-logloss:0.38231	validation_1-logloss:0.37482
# [96]	validation_0-logloss:0.38194	validation_1-logloss:0.37450
# [97]	validation_0-logloss:0.38147	validation_1-logloss:0.37529
# [98]	validation_0-logloss:0.38125	validation_1-logloss:0.37556
# [99]	validation_0-logloss:0.38099	validation_1-logloss:0.37513
# [100]	validation_0-logloss:0.38058	validation_1-logloss:0.37501
# [101]	validation_0-logloss:0.38026	validation_1-logloss:0.37487
# [102]	validation_0-logloss:0.37987	validation_1-logloss:0.37473
# [103]	validation_0-logloss:0.37958	validation_1-logloss:0.37520
# [104]	validation_0-logloss:0.37929	validation_1-logloss:0.37508
# [105]	validation_0-logloss:0.37902	validation_1-logloss:0.37539
# [106]	validation_0-logloss:0.37835	validation_1-logloss:0.37642
# [107]	validation_0-logloss:0.37798	validation_1-logloss:0.37657
# [108]	validation_0-logloss:0.37769	validation_1-logloss:0.37645
# [109]	validation_0-logloss:0.37730	validation_1-logloss:0.37668
# [110]	validation_0-logloss:0.37699	validation_1-logloss:0.37646
# [111]	validation_0-logloss:0.37670	validation_1-logloss:0.37649
# 오차 행렬
# [[98 12]
#  [22 47]]
# 정확도: 0.8101, 정밀도: 0.7966, 재현율: 0.6812,    F1: 0.7344, AUC:0.8958
# /opt/homebrew/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
predict_titanic_pred_xgb_python_ealy = xgb_wrapper.predict(predict_df)
preds_xgb_python_ealy = [ 1 if x > 0.5 else 0 for x in predict_titanic_pred_xgb_python_ealy]
print(f"predict_titanic_Voting 예측: {predict_titanic_pred_xgb_python_ealy[:10]}")
print('예측값 10개만 표시:',preds_xgb_python_ealy[:10], "\n")

gender_submission_df['Survived'] = preds_xgb_python_ealy
gender_submission_df.to_csv('titanic_submission_xgb_python_ealy.csv',index=False)
gender_submission_df
# Out:
# predict_titanic_Voting 예측: [0 1 0 0 0 0 1 0 1 0]
# 예측값 10개만 표시: [0, 1, 0, 0, 0, 0, 1, 0, 1, 0]
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
# early_stopping_rounds를 10으로 설정하고 재 학습. 
xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=10, eval_metric="logloss", eval_set=evals, verbose=True)

ws10_preds = xgb_wrapper.predict(X_test)
ws10_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
get_clf_eval(y_test , ws10_preds, ws10_pred_proba)

fig, ax = plt.subplots(figsize=(10, 5))
plot_importance(xgb_wrapper, ax=ax)
# Out:
# [0]	validation_0-logloss:0.65423	validation_1-logloss:0.57225
# [1]	validation_0-logloss:0.63510	validation_1-logloss:0.55531
# [2]	validation_0-logloss:0.61775	validation_1-logloss:0.53974
# [3]	validation_0-logloss:0.60199	validation_1-logloss:0.52552
# [4]	validation_0-logloss:0.58761	validation_1-logloss:0.51312
# [5]	validation_0-logloss:0.57446	validation_1-logloss:0.50100
# [6]	validation_0-logloss:0.56242	validation_1-logloss:0.48986
# [7]	validation_0-logloss:0.55137	validation_1-logloss:0.48019
# [8]	validation_0-logloss:0.54121	validation_1-logloss:0.47065
# [9]	validation_0-logloss:0.53186	validation_1-logloss:0.46176
# [10]	validation_0-logloss:0.52325	validation_1-logloss:0.45382
# [11]	validation_0-logloss:0.51529	validation_1-logloss:0.44619
# [12]	validation_0-logloss:0.50795	validation_1-logloss:0.43910
# [13]	validation_0-logloss:0.50116	validation_1-logloss:0.43250
# [14]	validation_0-logloss:0.49487	validation_1-logloss:0.42659
# [15]	validation_0-logloss:0.48906	validation_1-logloss:0.42081
# [16]	validation_0-logloss:0.48377	validation_1-logloss:0.41552
# [17]	validation_0-logloss:0.47875	validation_1-logloss:0.41071
# [18]	validation_0-logloss:0.47403	validation_1-logloss:0.40696
# [19]	validation_0-logloss:0.46976	validation_1-logloss:0.40281
# [20]	validation_0-logloss:0.46563	validation_1-logloss:0.40023
# [21]	validation_0-logloss:0.46176	validation_1-logloss:0.39705
# [22]	validation_0-logloss:0.45814	validation_1-logloss:0.39466
# [23]	validation_0-logloss:0.45473	validation_1-logloss:0.39184
# [24]	validation_0-logloss:0.45164	validation_1-logloss:0.38865
# [25]	validation_0-logloss:0.44861	validation_1-logloss:0.38682
# [26]	validation_0-logloss:0.44587	validation_1-logloss:0.38517
# [27]	validation_0-logloss:0.44320	validation_1-logloss:0.38223
# [28]	validation_0-logloss:0.44065	validation_1-logloss:0.38086
# [29]	validation_0-logloss:0.43843	validation_1-logloss:0.37952
# [30]	validation_0-logloss:0.43636	validation_1-logloss:0.37757
# [31]	validation_0-logloss:0.43420	validation_1-logloss:0.37708
# [32]	validation_0-logloss:0.43227	validation_1-logloss:0.37594
# [33]	validation_0-logloss:0.43046	validation_1-logloss:0.37461
# [34]	validation_0-logloss:0.42875	validation_1-logloss:0.37406
# [35]	validation_0-logloss:0.42713	validation_1-logloss:0.37371
# [36]	validation_0-logloss:0.42540	validation_1-logloss:0.37325
# [37]	validation_0-logloss:0.42392	validation_1-logloss:0.37153
# [38]	validation_0-logloss:0.42251	validation_1-logloss:0.37169
# [39]	validation_0-logloss:0.42106	validation_1-logloss:0.37067
# [40]	validation_0-logloss:0.41961	validation_1-logloss:0.37050
# [41]	validation_0-logloss:0.41838	validation_1-logloss:0.37076
# [42]	validation_0-logloss:0.41720	validation_1-logloss:0.36997
# [43]	validation_0-logloss:0.41621	validation_1-logloss:0.36922
# [44]	validation_0-logloss:0.41502	validation_1-logloss:0.36892
# [45]	validation_0-logloss:0.41389	validation_1-logloss:0.36909
# [46]	validation_0-logloss:0.41284	validation_1-logloss:0.36901
# [47]	validation_0-logloss:0.41176	validation_1-logloss:0.36862
# [48]	validation_0-logloss:0.41069	validation_1-logloss:0.36841
# [49]	validation_0-logloss:0.40976	validation_1-logloss:0.36838
# [50]	validation_0-logloss:0.40877	validation_1-logloss:0.36784
# [51]	validation_0-logloss:0.40780	validation_1-logloss:0.36803
# [52]	validation_0-logloss:0.40698	validation_1-logloss:0.36898
# [53]	validation_0-logloss:0.40608	validation_1-logloss:0.36809
# [54]	validation_0-logloss:0.40518	validation_1-logloss:0.36831
# [55]	validation_0-logloss:0.40445	validation_1-logloss:0.36924
# [56]	validation_0-logloss:0.40362	validation_1-logloss:0.36793
# [57]	validation_0-logloss:0.40280	validation_1-logloss:0.36819
# [58]	validation_0-logloss:0.40214	validation_1-logloss:0.36911
# [59]	validation_0-logloss:0.40138	validation_1-logloss:0.36882
# [60]	validation_0-logloss:0.40065	validation_1-logloss:0.36760
# [61]	validation_0-logloss:0.39989	validation_1-logloss:0.36740
# [62]	validation_0-logloss:0.39922	validation_1-logloss:0.36715
# [63]	validation_0-logloss:0.39850	validation_1-logloss:0.36757
# [64]	validation_0-logloss:0.39788	validation_1-logloss:0.36735
# [65]	validation_0-logloss:0.39736	validation_1-logloss:0.36827
# [66]	validation_0-logloss:0.39673	validation_1-logloss:0.36770
# [67]	validation_0-logloss:0.39619	validation_1-logloss:0.36752
# [68]	validation_0-logloss:0.39555	validation_1-logloss:0.36798
# [69]	validation_0-logloss:0.39505	validation_1-logloss:0.36782
# [70]	validation_0-logloss:0.39447	validation_1-logloss:0.36732
# [71]	validation_0-logloss:0.39389	validation_1-logloss:0.36831
# 오차 행렬
# [[98 12]
#  [22 47]]
# 정확도: 0.8101, 정밀도: 0.7966, 재현율: 0.6812,    F1: 0.7344, AUC:0.8958
# /opt/homebrew/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# early_stopping_rounds를 10으로 설정하고 재 학습. 
xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=100, eval_metric="logloss", eval_set=evals, verbose=True)

ws10_preds = xgb_wrapper.predict(X_test)
ws10_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
get_clf_eval(y_test , ws10_preds, ws10_pred_proba)

fig, ax = plt.subplots(figsize=(10, 5))
plot_importance(xgb_wrapper, ax=ax)
# Out:
# [0]	validation_0-logloss:0.65423	validation_1-logloss:0.57225
# [1]	validation_0-logloss:0.63510	validation_1-logloss:0.55531
# [2]	validation_0-logloss:0.61775	validation_1-logloss:0.53974
# [3]	validation_0-logloss:0.60199	validation_1-logloss:0.52552
# [4]	validation_0-logloss:0.58761	validation_1-logloss:0.51312
# [5]	validation_0-logloss:0.57446	validation_1-logloss:0.50100
# [6]	validation_0-logloss:0.56242	validation_1-logloss:0.48986
# [7]	validation_0-logloss:0.55137	validation_1-logloss:0.48019
# [8]	validation_0-logloss:0.54121	validation_1-logloss:0.47065
# [9]	validation_0-logloss:0.53186	validation_1-logloss:0.46176
# [10]	validation_0-logloss:0.52325	validation_1-logloss:0.45382
# [11]	validation_0-logloss:0.51529	validation_1-logloss:0.44619
# [12]	validation_0-logloss:0.50795	validation_1-logloss:0.43910
# [13]	validation_0-logloss:0.50116	validation_1-logloss:0.43250
# [14]	validation_0-logloss:0.49487	validation_1-logloss:0.42659
# [15]	validation_0-logloss:0.48906	validation_1-logloss:0.42081
# [16]	validation_0-logloss:0.48377	validation_1-logloss:0.41552
# [17]	validation_0-logloss:0.47875	validation_1-logloss:0.41071
# [18]	validation_0-logloss:0.47403	validation_1-logloss:0.40696
# [19]	validation_0-logloss:0.46976	validation_1-logloss:0.40281
# [20]	validation_0-logloss:0.46563	validation_1-logloss:0.40023
# [21]	validation_0-logloss:0.46176	validation_1-logloss:0.39705
# [22]	validation_0-logloss:0.45814	validation_1-logloss:0.39466
# [23]	validation_0-logloss:0.45473	validation_1-logloss:0.39184
# [24]	validation_0-logloss:0.45164	validation_1-logloss:0.38865
# [25]	validation_0-logloss:0.44861	validation_1-logloss:0.38682
# [26]	validation_0-logloss:0.44587	validation_1-logloss:0.38517
# [27]	validation_0-logloss:0.44320	validation_1-logloss:0.38223
# [28]	validation_0-logloss:0.44065	validation_1-logloss:0.38086
# [29]	validation_0-logloss:0.43843	validation_1-logloss:0.37952
# [30]	validation_0-logloss:0.43636	validation_1-logloss:0.37757
# [31]	validation_0-logloss:0.43420	validation_1-logloss:0.37708
# [32]	validation_0-logloss:0.43227	validation_1-logloss:0.37594
# [33]	validation_0-logloss:0.43046	validation_1-logloss:0.37461
# [34]	validation_0-logloss:0.42875	validation_1-logloss:0.37406
# [35]	validation_0-logloss:0.42713	validation_1-logloss:0.37371
# [36]	validation_0-logloss:0.42540	validation_1-logloss:0.37325
# [37]	validation_0-logloss:0.42392	validation_1-logloss:0.37153
# [38]	validation_0-logloss:0.42251	validation_1-logloss:0.37169
# [39]	validation_0-logloss:0.42106	validation_1-logloss:0.37067
# [40]	validation_0-logloss:0.41961	validation_1-logloss:0.37050
# [41]	validation_0-logloss:0.41838	validation_1-logloss:0.37076
# [42]	validation_0-logloss:0.41720	validation_1-logloss:0.36997
# [43]	validation_0-logloss:0.41621	validation_1-logloss:0.36922
# [44]	validation_0-logloss:0.41502	validation_1-logloss:0.36892
# [45]	validation_0-logloss:0.41389	validation_1-logloss:0.36909
# [46]	validation_0-logloss:0.41284	validation_1-logloss:0.36901
# [47]	validation_0-logloss:0.41176	validation_1-logloss:0.36862
# [48]	validation_0-logloss:0.41069	validation_1-logloss:0.36841
# [49]	validation_0-logloss:0.40976	validation_1-logloss:0.36838
# [50]	validation_0-logloss:0.40877	validation_1-logloss:0.36784
# [51]	validation_0-logloss:0.40780	validation_1-logloss:0.36803
# [52]	validation_0-logloss:0.40698	validation_1-logloss:0.36898
# [53]	validation_0-logloss:0.40608	validation_1-logloss:0.36809
# [54]	validation_0-logloss:0.40518	validation_1-logloss:0.36831
# [55]	validation_0-logloss:0.40445	validation_1-logloss:0.36924
# [56]	validation_0-logloss:0.40362	validation_1-logloss:0.36793
# [57]	validation_0-logloss:0.40280	validation_1-logloss:0.36819
# [58]	validation_0-logloss:0.40214	validation_1-logloss:0.36911
# [59]	validation_0-logloss:0.40138	validation_1-logloss:0.36882
# [60]	validation_0-logloss:0.40065	validation_1-logloss:0.36760
# [61]	validation_0-logloss:0.39989	validation_1-logloss:0.36740
# [62]	validation_0-logloss:0.39922	validation_1-logloss:0.36715
# [63]	validation_0-logloss:0.39850	validation_1-logloss:0.36757
# [64]	validation_0-logloss:0.39788	validation_1-logloss:0.36735
# [65]	validation_0-logloss:0.39736	validation_1-logloss:0.36827
# [66]	validation_0-logloss:0.39673	validation_1-logloss:0.36770
# [67]	validation_0-logloss:0.39619	validation_1-logloss:0.36752
# [68]	validation_0-logloss:0.39555	validation_1-logloss:0.36798
# [69]	validation_0-logloss:0.39505	validation_1-logloss:0.36782
# [70]	validation_0-logloss:0.39447	validation_1-logloss:0.36732
# /opt/homebrew/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [71]	validation_0-logloss:0.39389	validation_1-logloss:0.36831
# [72]	validation_0-logloss:0.39343	validation_1-logloss:0.36817
# [73]	validation_0-logloss:0.39303	validation_1-logloss:0.36852
# [74]	validation_0-logloss:0.39250	validation_1-logloss:0.36805
# [75]	validation_0-logloss:0.39181	validation_1-logloss:0.36862
# [76]	validation_0-logloss:0.39141	validation_1-logloss:0.36852
# [77]	validation_0-logloss:0.39092	validation_1-logloss:0.36810
# [78]	validation_0-logloss:0.39055	validation_1-logloss:0.36801
# [79]	validation_0-logloss:0.39006	validation_1-logloss:0.36950
# [80]	validation_0-logloss:0.38971	validation_1-logloss:0.36917
# [81]	validation_0-logloss:0.38872	validation_1-logloss:0.37019
# [82]	validation_0-logloss:0.38826	validation_1-logloss:0.37093
# [83]	validation_0-logloss:0.38796	validation_1-logloss:0.37118
# [84]	validation_0-logloss:0.38742	validation_1-logloss:0.37166
# [85]	validation_0-logloss:0.38698	validation_1-logloss:0.37129
# [86]	validation_0-logloss:0.38668	validation_1-logloss:0.37123
# [87]	validation_0-logloss:0.38641	validation_1-logloss:0.37157
# [88]	validation_0-logloss:0.38554	validation_1-logloss:0.37259
# [89]	validation_0-logloss:0.38505	validation_1-logloss:0.37238
# [90]	validation_0-logloss:0.38465	validation_1-logloss:0.37204
# [91]	validation_0-logloss:0.38423	validation_1-logloss:0.37274
# [92]	validation_0-logloss:0.38344	validation_1-logloss:0.37378
# [93]	validation_0-logloss:0.38299	validation_1-logloss:0.37360
# [94]	validation_0-logloss:0.38273	validation_1-logloss:0.37429
# [95]	validation_0-logloss:0.38231	validation_1-logloss:0.37482
# [96]	validation_0-logloss:0.38194	validation_1-logloss:0.37450
# [97]	validation_0-logloss:0.38147	validation_1-logloss:0.37529
# [98]	validation_0-logloss:0.38125	validation_1-logloss:0.37556
# [99]	validation_0-logloss:0.38099	validation_1-logloss:0.37513
# [100]	validation_0-logloss:0.38058	validation_1-logloss:0.37501
# [101]	validation_0-logloss:0.38026	validation_1-logloss:0.37487
# [102]	validation_0-logloss:0.37987	validation_1-logloss:0.37473
# [103]	validation_0-logloss:0.37958	validation_1-logloss:0.37520
# [104]	validation_0-logloss:0.37929	validation_1-logloss:0.37508
# [105]	validation_0-logloss:0.37902	validation_1-logloss:0.37539
# [106]	validation_0-logloss:0.37835	validation_1-logloss:0.37642
# [107]	validation_0-logloss:0.37798	validation_1-logloss:0.37657
# [108]	validation_0-logloss:0.37769	validation_1-logloss:0.37645
# [109]	validation_0-logloss:0.37730	validation_1-logloss:0.37668
# [110]	validation_0-logloss:0.37699	validation_1-logloss:0.37646
# [111]	validation_0-logloss:0.37670	validation_1-logloss:0.37649
# [112]	validation_0-logloss:0.37646	validation_1-logloss:0.37682
# [113]	validation_0-logloss:0.37585	validation_1-logloss:0.37780
# [114]	validation_0-logloss:0.37559	validation_1-logloss:0.37777
# [115]	validation_0-logloss:0.37537	validation_1-logloss:0.37801
# [116]	validation_0-logloss:0.37515	validation_1-logloss:0.37762
# [117]	validation_0-logloss:0.37484	validation_1-logloss:0.37775
# [118]	validation_0-logloss:0.37464	validation_1-logloss:0.37756
# [119]	validation_0-logloss:0.37407	validation_1-logloss:0.37852
# [120]	validation_0-logloss:0.37383	validation_1-logloss:0.37884
# [121]	validation_0-logloss:0.37363	validation_1-logloss:0.37940
# [122]	validation_0-logloss:0.37343	validation_1-logloss:0.37903
# [123]	validation_0-logloss:0.37313	validation_1-logloss:0.37906
# [124]	validation_0-logloss:0.37274	validation_1-logloss:0.37985
# [125]	validation_0-logloss:0.37222	validation_1-logloss:0.38085
# [126]	validation_0-logloss:0.37180	validation_1-logloss:0.38083
# [127]	validation_0-logloss:0.37133	validation_1-logloss:0.38179
# [128]	validation_0-logloss:0.37110	validation_1-logloss:0.38211
# [129]	validation_0-logloss:0.37088	validation_1-logloss:0.38238
# [130]	validation_0-logloss:0.37069	validation_1-logloss:0.38201
# [131]	validation_0-logloss:0.37031	validation_1-logloss:0.38201
# [132]	validation_0-logloss:0.36988	validation_1-logloss:0.38293
# [133]	validation_0-logloss:0.36959	validation_1-logloss:0.38286
# [134]	validation_0-logloss:0.36925	validation_1-logloss:0.38356
# [135]	validation_0-logloss:0.36885	validation_1-logloss:0.38456
# [136]	validation_0-logloss:0.36849	validation_1-logloss:0.38457
# [137]	validation_0-logloss:0.36828	validation_1-logloss:0.38489
# [138]	validation_0-logloss:0.36796	validation_1-logloss:0.38557
# [139]	validation_0-logloss:0.36758	validation_1-logloss:0.38566
# [140]	validation_0-logloss:0.36725	validation_1-logloss:0.38561
# [141]	validation_0-logloss:0.36693	validation_1-logloss:0.38565
# [142]	validation_0-logloss:0.36667	validation_1-logloss:0.38569
# [143]	validation_0-logloss:0.36651	validation_1-logloss:0.38591
# [144]	validation_0-logloss:0.36621	validation_1-logloss:0.38589
# [145]	validation_0-logloss:0.36585	validation_1-logloss:0.38677
# [146]	validation_0-logloss:0.36566	validation_1-logloss:0.38710
# [147]	validation_0-logloss:0.36534	validation_1-logloss:0.38811
# [148]	validation_0-logloss:0.36519	validation_1-logloss:0.38840
# [149]	validation_0-logloss:0.36497	validation_1-logloss:0.38862
# [150]	validation_0-logloss:0.36467	validation_1-logloss:0.38931
# [151]	validation_0-logloss:0.36433	validation_1-logloss:0.38999
# [152]	validation_0-logloss:0.36406	validation_1-logloss:0.39090
# [153]	validation_0-logloss:0.36388	validation_1-logloss:0.39087
# [154]	validation_0-logloss:0.36374	validation_1-logloss:0.39094
# [155]	validation_0-logloss:0.36334	validation_1-logloss:0.39057
# [156]	validation_0-logloss:0.36303	validation_1-logloss:0.39129
# [157]	validation_0-logloss:0.36283	validation_1-logloss:0.39150
# [158]	validation_0-logloss:0.36249	validation_1-logloss:0.39233
# [159]	validation_0-logloss:0.36220	validation_1-logloss:0.39250
# [160]	validation_0-logloss:0.36191	validation_1-logloss:0.39255
# [161]	validation_0-logloss:0.36150	validation_1-logloss:0.39234
# [162]	validation_0-logloss:0.36123	validation_1-logloss:0.39267
# 오차 행렬
# [[98 12]
#  [22 47]]
# 정확도: 0.8101, 정밀도: 0.7966, 재현율: 0.6812,    F1: 0.7344, AUC:0.8958
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# # HyperOpt

# %%
xgb_clf = XGBClassifier(n_estimators=500, learning_rate=0.05, early_stopping_rounds=100, eval_metric='logloss')

# 성능 평가 지표를 auc로, 조기 중단 파라미터는 100으로 설정하고 학습 수행. 
# 다중 분류 문제에서는 'multi_logloss'가 적합 / 회귀 문제에서는 'rmse', 'mae', 'mse' 등이 주로 사용
xgb_clf.fit(X_tr, y_tr, eval_set=[(X_tr, y_tr), (X_val, y_val)])
y_pred = xgb_clf.predict(X_test)

# 오차 행렬
cm = confusion_matrix(y_test, y_pred)
print(cm)

xgb_roc_score = roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:, 1])
print('ROC AUC: {0:.4f}'.format(xgb_roc_score))
# Out:
# [0]	validation_0-logloss:0.65163	validation_1-logloss:0.57158
# [1]	validation_0-logloss:0.63006	validation_1-logloss:0.55456
# [2]	validation_0-logloss:0.61046	validation_1-logloss:0.53908
# [3]	validation_0-logloss:0.59258	validation_1-logloss:0.52499
# [4]	validation_0-logloss:0.57624	validation_1-logloss:0.51214
# [5]	validation_0-logloss:0.56125	validation_1-logloss:0.50039
# [6]	validation_0-logloss:0.54749	validation_1-logloss:0.48966
# [7]	validation_0-logloss:0.53482	validation_1-logloss:0.47981
# [8]	validation_0-logloss:0.52322	validation_1-logloss:0.47182
# [9]	validation_0-logloss:0.51245	validation_1-logloss:0.46364
# [10]	validation_0-logloss:0.50240	validation_1-logloss:0.45749
# [11]	validation_0-logloss:0.49310	validation_1-logloss:0.45064
# [12]	validation_0-logloss:0.48445	validation_1-logloss:0.44546
# [13]	validation_0-logloss:0.47636	validation_1-logloss:0.44058
# [14]	validation_0-logloss:0.46889	validation_1-logloss:0.43637
# [15]	validation_0-logloss:0.46186	validation_1-logloss:0.43136
# [16]	validation_0-logloss:0.45530	validation_1-logloss:0.42777
# [17]	validation_0-logloss:0.44896	validation_1-logloss:0.42428
# [18]	validation_0-logloss:0.44305	validation_1-logloss:0.42156
# [19]	validation_0-logloss:0.43752	validation_1-logloss:0.41894
# [20]	validation_0-logloss:0.43216	validation_1-logloss:0.41612
# [21]	validation_0-logloss:0.42730	validation_1-logloss:0.41389
# [22]	validation_0-logloss:0.42269	validation_1-logloss:0.41170
# [23]	validation_0-logloss:0.41840	validation_1-logloss:0.40984
# [24]	validation_0-logloss:0.41385	validation_1-logloss:0.40832
# [25]	validation_0-logloss:0.40981	validation_1-logloss:0.40733
# [26]	validation_0-logloss:0.40633	validation_1-logloss:0.40610
# [27]	validation_0-logloss:0.40254	validation_1-logloss:0.40502
# [28]	validation_0-logloss:0.39901	validation_1-logloss:0.40426
# [29]	validation_0-logloss:0.39599	validation_1-logloss:0.40394
# [30]	validation_0-logloss:0.39269	validation_1-logloss:0.40322
# [31]	validation_0-logloss:0.38982	validation_1-logloss:0.40214
# [32]	validation_0-logloss:0.38690	validation_1-logloss:0.40183
# [33]	validation_0-logloss:0.38411	validation_1-logloss:0.40172
# [34]	validation_0-logloss:0.38137	validation_1-logloss:0.40156
# [35]	validation_0-logloss:0.37888	validation_1-logloss:0.40157
# [36]	validation_0-logloss:0.37646	validation_1-logloss:0.40174
# [37]	validation_0-logloss:0.37410	validation_1-logloss:0.40210
# [38]	validation_0-logloss:0.37209	validation_1-logloss:0.40182
# [39]	validation_0-logloss:0.36984	validation_1-logloss:0.40205
# [40]	validation_0-logloss:0.36786	validation_1-logloss:0.40241
# [41]	validation_0-logloss:0.36590	validation_1-logloss:0.40143
# [42]	validation_0-logloss:0.36419	validation_1-logloss:0.40164
# [43]	validation_0-logloss:0.36242	validation_1-logloss:0.40224
# [44]	validation_0-logloss:0.36069	validation_1-logloss:0.40195
# [45]	validation_0-logloss:0.35913	validation_1-logloss:0.40137
# [46]	validation_0-logloss:0.35755	validation_1-logloss:0.40206
# [47]	validation_0-logloss:0.35606	validation_1-logloss:0.40272
# [48]	validation_0-logloss:0.35466	validation_1-logloss:0.40380
# [49]	validation_0-logloss:0.35326	validation_1-logloss:0.40316
# [50]	validation_0-logloss:0.35204	validation_1-logloss:0.40291
# [51]	validation_0-logloss:0.35085	validation_1-logloss:0.40308
# [52]	validation_0-logloss:0.34962	validation_1-logloss:0.40337
# [53]	validation_0-logloss:0.34840	validation_1-logloss:0.40282
# [54]	validation_0-logloss:0.34725	validation_1-logloss:0.40309
# [55]	validation_0-logloss:0.34616	validation_1-logloss:0.40287
# [56]	validation_0-logloss:0.34495	validation_1-logloss:0.40260
# [57]	validation_0-logloss:0.34395	validation_1-logloss:0.40355
# [58]	validation_0-logloss:0.34294	validation_1-logloss:0.40317
# [59]	validation_0-logloss:0.34207	validation_1-logloss:0.40415
# [60]	validation_0-logloss:0.34100	validation_1-logloss:0.40396
# [61]	validation_0-logloss:0.34017	validation_1-logloss:0.40417
# [62]	validation_0-logloss:0.33923	validation_1-logloss:0.40431
# [63]	validation_0-logloss:0.33836	validation_1-logloss:0.40542
# [64]	validation_0-logloss:0.33763	validation_1-logloss:0.40587
# [65]	validation_0-logloss:0.33651	validation_1-logloss:0.40695
# [66]	validation_0-logloss:0.33584	validation_1-logloss:0.40806
# [67]	validation_0-logloss:0.33513	validation_1-logloss:0.40870
# [68]	validation_0-logloss:0.33423	validation_1-logloss:0.40920
# [69]	validation_0-logloss:0.33358	validation_1-logloss:0.41014
# [70]	validation_0-logloss:0.33281	validation_1-logloss:0.40963
# [71]	validation_0-logloss:0.33211	validation_1-logloss:0.41013
# [72]	validation_0-logloss:0.33156	validation_1-logloss:0.41048
# [73]	validation_0-logloss:0.33102	validation_1-logloss:0.41039
# [74]	validation_0-logloss:0.33049	validation_1-logloss:0.41041
# [75]	validation_0-logloss:0.32992	validation_1-logloss:0.41061
# [76]	validation_0-logloss:0.32948	validation_1-logloss:0.41080
# [77]	validation_0-logloss:0.32898	validation_1-logloss:0.41057
# [78]	validation_0-logloss:0.32844	validation_1-logloss:0.41077
# [79]	validation_0-logloss:0.32793	validation_1-logloss:0.41141
# [80]	validation_0-logloss:0.32735	validation_1-logloss:0.41085
# [81]	validation_0-logloss:0.32692	validation_1-logloss:0.41102
# [82]	validation_0-logloss:0.32630	validation_1-logloss:0.41184
# [83]	validation_0-logloss:0.32589	validation_1-logloss:0.41179
# [84]	validation_0-logloss:0.32533	validation_1-logloss:0.41268
# [85]	validation_0-logloss:0.32482	validation_1-logloss:0.41319
# [86]	validation_0-logloss:0.32395	validation_1-logloss:0.41376
# [87]	validation_0-logloss:0.32352	validation_1-logloss:0.41363
# [88]	validation_0-logloss:0.32309	validation_1-logloss:0.41469
# [89]	validation_0-logloss:0.32237	validation_1-logloss:0.41547
# [90]	validation_0-logloss:0.32130	validation_1-logloss:0.41757
# [91]	validation_0-logloss:0.32028	validation_1-logloss:0.41936
# [92]	validation_0-logloss:0.31930	validation_1-logloss:0.42069
# [93]	validation_0-logloss:0.31889	validation_1-logloss:0.42089
# [94]	validation_0-logloss:0.31797	validation_1-logloss:0.42226
# [95]	validation_0-logloss:0.31757	validation_1-logloss:0.42247
# [96]	validation_0-logloss:0.31670	validation_1-logloss:0.42378
# [97]	validation_0-logloss:0.31622	validation_1-logloss:0.42416
# [98]	validation_0-logloss:0.31545	validation_1-logloss:0.42570
# [99]	validation_0-logloss:0.31508	validation_1-logloss:0.42563
# [100]	validation_0-logloss:0.31436	validation_1-logloss:0.42782
# [101]	validation_0-logloss:0.31400	validation_1-logloss:0.42776
# [102]	validation_0-logloss:0.31333	validation_1-logloss:0.42938
# [103]	validation_0-logloss:0.31251	validation_1-logloss:0.43076
# [104]	validation_0-logloss:0.31180	validation_1-logloss:0.43243
# [105]	validation_0-logloss:0.31112	validation_1-logloss:0.43428
# [106]	validation_0-logloss:0.31082	validation_1-logloss:0.43493
# [107]	validation_0-logloss:0.31051	validation_1-logloss:0.43540
# [108]	validation_0-logloss:0.30977	validation_1-logloss:0.43675
# [109]	validation_0-logloss:0.30951	validation_1-logloss:0.43712
# [110]	validation_0-logloss:0.30880	validation_1-logloss:0.43854
# [111]	validation_0-logloss:0.30817	validation_1-logloss:0.44049
# [112]	validation_0-logloss:0.30793	validation_1-logloss:0.44084
# [113]	validation_0-logloss:0.30765	validation_1-logloss:0.44104
# [114]	validation_0-logloss:0.30707	validation_1-logloss:0.44281
# [115]	validation_0-logloss:0.30657	validation_1-logloss:0.44459
# [116]	validation_0-logloss:0.30597	validation_1-logloss:0.44572
# [117]	validation_0-logloss:0.30550	validation_1-logloss:0.44723
# [118]	validation_0-logloss:0.30488	validation_1-logloss:0.44833
# [119]	validation_0-logloss:0.30437	validation_1-logloss:0.45009
# [120]	validation_0-logloss:0.30408	validation_1-logloss:0.45055
# [121]	validation_0-logloss:0.30381	validation_1-logloss:0.45076
# [122]	validation_0-logloss:0.30333	validation_1-logloss:0.45212
# [123]	validation_0-logloss:0.30270	validation_1-logloss:0.45286
# [124]	validation_0-logloss:0.30244	validation_1-logloss:0.45306
# [125]	validation_0-logloss:0.30193	validation_1-logloss:0.45447
# [126]	validation_0-logloss:0.30172	validation_1-logloss:0.45502
# [127]	validation_0-logloss:0.30112	validation_1-logloss:0.45590
# [128]	validation_0-logloss:0.30082	validation_1-logloss:0.45566
# [129]	validation_0-logloss:0.30035	validation_1-logloss:0.45718
# [130]	validation_0-logloss:0.30007	validation_1-logloss:0.45672
# [131]	validation_0-logloss:0.29956	validation_1-logloss:0.45780
# [132]	validation_0-logloss:0.29910	validation_1-logloss:0.45935
# [133]	validation_0-logloss:0.29863	validation_1-logloss:0.46081
# [134]	validation_0-logloss:0.29825	validation_1-logloss:0.46017
# [135]	validation_0-logloss:0.29780	validation_1-logloss:0.46172
# [136]	validation_0-logloss:0.29741	validation_1-logloss:0.46249
# [137]	validation_0-logloss:0.29707	validation_1-logloss:0.46195
# [138]	validation_0-logloss:0.29675	validation_1-logloss:0.46321
# [139]	validation_0-logloss:0.29633	validation_1-logloss:0.46480
# [140]	validation_0-logloss:0.29601	validation_1-logloss:0.46422
# [141]	validation_0-logloss:0.29556	validation_1-logloss:0.46413
# [142]	validation_0-logloss:0.29518	validation_1-logloss:0.46568
# [143]	validation_0-logloss:0.29490	validation_1-logloss:0.46538
# [144]	validation_0-logloss:0.29466	validation_1-logloss:0.46520
# [[100  10]
#  [ 22  47]]
# ROC AUC: 0.8702

# %%
from hyperopt import hp

# max_depth는 5에서 15까지 1간격으로, min_child_weight는 1에서 6까지 1간격으로
# colsample_bytree는 0.5에서 0.95사이, learning_rate는 0.01에서 0.2사이 정규 분포된 값으로 검색. 
# hp.uniform 균일 분포(Uniform Distribution)에서 하이퍼파라미터 값을 샘플링
# 균일 분포란 특정 구간 내에서 모든 값이 동일한 확률을 가지는 확률 분포를 말합니다. 즉, 어떤 값이 선택될 확률이 균일하게 분포되어 있다.
# [0.5, 0.95] 구간 내에서 균일하게 분포된 값을 'colsample_bytree' 하이퍼파라미터에 대한 후보 값으로 샘플링 = 0.5와 0.95 사이의 값들을 후보로 고려
xgb_search_space = {'max_depth': hp.quniform('max_depth', 2, 15, 1), 
                    'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
                    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 0.95),
                    'learning_rate': hp.uniform('learning_rate', 0.01, 0.2)
}

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score

# 목적 함수 설정. 
# 추후 fmin()에서 입력된 search_space값으로 XGBClassifier 교차 검증 학습 후 -1* roc_auc 평균 값을 반환.  
def objective_func(search_space):
    xgb_clf = XGBClassifier(n_estimators=100,
                            max_depth=int(search_space['max_depth']),
                            min_child_weight=int(search_space['min_child_weight']),
                            colsample_bytree=search_space['colsample_bytree'],
                            learning_rate=search_space['learning_rate'],
                            early_stopping_rounds=30,
                            eval_metric='logloss')
    
    # 3개 k-fold 방식으로 평가된 roc_auc 지표를 담는 list
    roc_auc_list= []
    
    # 5개 k-fold방식 적용 
    kf = KFold(n_splits=5)
    
    # X_train을 다시 학습과 검증용 데이터로 분리
    # X_train 데이터에 대한 학습 인덱스(tr_index)와 검증 인덱스(val_index)를 얻는다.
    for tr_index, val_index in kf.split(X_train):
        # kf.split(X_train)으로 추출된 학습과 검증 index값으로 학습과 검증 데이터 세트 분리 
        X_tr, y_tr = X_train.iloc[tr_index], y_train.iloc[tr_index]
        X_val, y_val = X_train.iloc[val_index], y_train.iloc[val_index]
        
        # early stopping은 30회로 설정하고 추출된 학습과 검증 데이터로 XGBClassifier 학습 수행.
        xgb_clf.fit(X_tr, y_tr, eval_set=[(X_tr, y_tr), (X_val, y_val)])
    
        # 1로 예측한 확률값 추출후 roc auc 계산하고 평균 roc auc 계산을 위해 list에 결과값 담음. 
        score = roc_auc_score(y_val, xgb_clf.predict_proba(X_val)[:, 1])
        roc_auc_list.append(score)
    
    # 5개 k-fold로 계산된 roc_auc값의 평균값을 반환하되, 
    # HyperOpt는 목적함수의 최소값을 위한 입력값을 찾으므로 -1을 곱한 뒤 반환. 
    return -1 * np.mean(roc_auc_list)

# %%
from hyperopt import fmin, tpe, Trials

trials = Trials()

# fmin()함수를 호출. max_evals지정된 횟수만큼 반복 후 목적함수의 최소값을 가지는 최적 입력값 추출.
best = fmin(fn=objective_func,
            space=xgb_search_space,
            algo=tpe.suggest,
            max_evals=50, # 최대 반복 횟수를 지정합니다.
            trials=trials,
            rstate=np.random.default_rng()
           )

print('best:', best)
# Out:
# [0]	validation_0-logloss:0.64399	validation_1-logloss:0.64181
# [1]	validation_0-logloss:0.63248	validation_1-logloss:0.63518
# [2]	validation_0-logloss:0.61080	validation_1-logloss:0.61899
# [3]	validation_0-logloss:0.60185	validation_1-logloss:0.61408
# [4]	validation_0-logloss:0.59323	validation_1-logloss:0.60958
# [5]	validation_0-logloss:0.58469	validation_1-logloss:0.60376
# [6]	validation_0-logloss:0.57625	validation_1-logloss:0.59884
# [7]	validation_0-logloss:0.56854	validation_1-logloss:0.59482
# [8]	validation_0-logloss:0.56146	validation_1-logloss:0.59015
# [9]	validation_0-logloss:0.54474	validation_1-logloss:0.57665
# [10]	validation_0-logloss:0.53119	validation_1-logloss:0.56702
# [11]	validation_0-logloss:0.52598	validation_1-logloss:0.56381
# [12]	validation_0-logloss:0.51413	validation_1-logloss:0.55435
# [13]	validation_0-logloss:0.50948	validation_1-logloss:0.55239
# [14]	validation_0-logloss:0.50489	validation_1-logloss:0.55014
# [15]	validation_0-logloss:0.49397	validation_1-logloss:0.54245
# [16]	validation_0-logloss:0.48495	validation_1-logloss:0.53582
# [17]	validation_0-logloss:0.48190	validation_1-logloss:0.53508
# [18]	validation_0-logloss:0.47398	validation_1-logloss:0.52899
# [19]	validation_0-logloss:0.46389	validation_1-logloss:0.52192
# [20]	validation_0-logloss:0.45623	validation_1-logloss:0.51569
# [21]	validation_0-logloss:0.44934	validation_1-logloss:0.51099
# [22]	validation_0-logloss:0.44167	validation_1-logloss:0.50574
# [23]	validation_0-logloss:0.43594	validation_1-logloss:0.50197
# [24]	validation_0-logloss:0.43311	validation_1-logloss:0.50037
# [25]	validation_0-logloss:0.43045	validation_1-logloss:0.49908
# [26]	validation_0-logloss:0.42460	validation_1-logloss:0.49302
# [27]	validation_0-logloss:0.42273	validation_1-logloss:0.49175
# [28]	validation_0-logloss:0.41780	validation_1-logloss:0.48950
# [29]	validation_0-logloss:0.41585	validation_1-logloss:0.48818
# [30]	validation_0-logloss:0.41376	validation_1-logloss:0.48692
# [31]	validation_0-logloss:0.40971	validation_1-logloss:0.48384
# [32]	validation_0-logloss:0.40585	validation_1-logloss:0.48148
# [33]	validation_0-logloss:0.40427	validation_1-logloss:0.48015
# [34]	validation_0-logloss:0.40221	validation_1-logloss:0.47932
# [35]	validation_0-logloss:0.39874	validation_1-logloss:0.47724
# [36]	validation_0-logloss:0.39558	validation_1-logloss:0.47450
# [37]	validation_0-logloss:0.39208	validation_1-logloss:0.47186
# [38]	validation_0-logloss:0.38936	validation_1-logloss:0.47065
# [39]	validation_0-logloss:0.38791	validation_1-logloss:0.47016
# [40]	validation_0-logloss:0.38675	validation_1-logloss:0.46901
# [41]	validation_0-logloss:0.38569	validation_1-logloss:0.46839
# [42]	validation_0-logloss:0.38470	validation_1-logloss:0.46714
# [43]	validation_0-logloss:0.38229	validation_1-logloss:0.46620
# [44]	validation_0-logloss:0.37924	validation_1-logloss:0.46357
# [45]	validation_0-logloss:0.37647	validation_1-logloss:0.46116
# [46]	validation_0-logloss:0.37565	validation_1-logloss:0.46135
# [47]	validation_0-logloss:0.37384	validation_1-logloss:0.46085
# [48]	validation_0-logloss:0.37153	validation_1-logloss:0.46039
# [49]	validation_0-logloss:0.37074	validation_1-logloss:0.46044
# [50]	validation_0-logloss:0.36999	validation_1-logloss:0.46056
# [51]	validation_0-logloss:0.36787	validation_1-logloss:0.45920
# [52]	validation_0-logloss:0.36569	validation_1-logloss:0.45654
# [53]	validation_0-logloss:0.36385	validation_1-logloss:0.45583
# [54]	validation_0-logloss:0.36249	validation_1-logloss:0.45481
# [55]	validation_0-logloss:0.36087	validation_1-logloss:0.45428
# [56]	validation_0-logloss:0.35974	validation_1-logloss:0.45401
# [57]	validation_0-logloss:0.35867	validation_1-logloss:0.45347
# [58]	validation_0-logloss:0.35726	validation_1-logloss:0.45316
# [59]	validation_0-logloss:0.35596	validation_1-logloss:0.45258
# [60]	validation_0-logloss:0.35449	validation_1-logloss:0.45202
# [61]	validation_0-logloss:0.35382	validation_1-logloss:0.45265
# [62]	validation_0-logloss:0.35218	validation_1-logloss:0.45195
# [63]	validation_0-logloss:0.35083	validation_1-logloss:0.45118
# [64]	validation_0-logloss:0.34953	validation_1-logloss:0.45070
# [65]	validation_0-logloss:0.34858	validation_1-logloss:0.45001
# [66]	validation_0-logloss:0.34738	validation_1-logloss:0.44970
# [67]	validation_0-logloss:0.34640	validation_1-logloss:0.44954
# [68]	validation_0-logloss:0.34595	validation_1-logloss:0.44951
# [69]	validation_0-logloss:0.34488	validation_1-logloss:0.44895
# [70]	validation_0-logloss:0.34441	validation_1-logloss:0.44927
# [71]	validation_0-logloss:0.34356	validation_1-logloss:0.44925
# [72]	validation_0-logloss:0.34301	validation_1-logloss:0.44962
# [73]	validation_0-logloss:0.34224	validation_1-logloss:0.44997
# [74]	validation_0-logloss:0.34134	validation_1-logloss:0.44958
# [75]	validation_0-logloss:0.34059	validation_1-logloss:0.44883
# [76]	validation_0-logloss:0.33979	validation_1-logloss:0.44792
# [77]	validation_0-logloss:0.33909	validation_1-logloss:0.44785
# [78]	validation_0-logloss:0.33832	validation_1-logloss:0.44763
# [79]	validation_0-logloss:0.33753	validation_1-logloss:0.44727
# [80]	validation_0-logloss:0.33666	validation_1-logloss:0.44714
# [81]	validation_0-logloss:0.33586	validation_1-logloss:0.44686
# [82]	validation_0-logloss:0.33517	validation_1-logloss:0.44717
# [83]	validation_0-logloss:0.33427	validation_1-logloss:0.44643
# [84]	validation_0-logloss:0.33385	validation_1-logloss:0.44606
# [85]	validation_0-logloss:0.33338	validation_1-logloss:0.44562
# [86]	validation_0-logloss:0.33287	validation_1-logloss:0.44571
# [87]	validation_0-logloss:0.33240	validation_1-logloss:0.44529
# [88]	validation_0-logloss:0.33205	validation_1-logloss:0.44518
# [89]	validation_0-logloss:0.33170	validation_1-logloss:0.44477
# [90]	validation_0-logloss:0.33127	validation_1-logloss:0.44458
# [91]	validation_0-logloss:0.33098	validation_1-logloss:0.44453
# [92]	validation_0-logloss:0.33072	validation_1-logloss:0.44450
# [93]	validation_0-logloss:0.33028	validation_1-logloss:0.44498
# [94]	validation_0-logloss:0.32971	validation_1-logloss:0.44483
# [95]	validation_0-logloss:0.32931	validation_1-logloss:0.44476
# [96]	validation_0-logloss:0.32902	validation_1-logloss:0.44453
# [97]	validation_0-logloss:0.32848	validation_1-logloss:0.44411
# [98]	validation_0-logloss:0.32808	validation_1-logloss:0.44447
# [99]	validation_0-logloss:0.32767	validation_1-logloss:0.44408
# [0]	validation_0-logloss:0.64924	validation_1-logloss:0.62385
# [1]	validation_0-logloss:0.63770	validation_1-logloss:0.61588
# [2]	validation_0-logloss:0.61717	validation_1-logloss:0.59632
# [3]	validation_0-logloss:0.60790	validation_1-logloss:0.59117
# [4]	validation_0-logloss:0.59917	validation_1-logloss:0.58498
# [5]	validation_0-logloss:0.59118	validation_1-logloss:0.57968
# [6]	validation_0-logloss:0.58289	validation_1-logloss:0.57470
# [7]	validation_0-logloss:0.57527	validation_1-logloss:0.56862
# [8]	validation_0-logloss:0.56856	validation_1-logloss:0.56398
# [9]	validation_0-logloss:0.55271	validation_1-logloss:0.54826
# [10]	validation_0-logloss:0.53974	validation_1-logloss:0.53708
# [11]	validation_0-logloss:0.53472	validation_1-logloss:0.53357
# [12]	validation_0-logloss:0.52285	validation_1-logloss:0.52399
# [13]	validation_0-logloss:0.51757	validation_1-logloss:0.52271
# [14]	validation_0-logloss:0.51274	validation_1-logloss:0.52109
# [15]	validation_0-logloss:0.50192	validation_1-logloss:0.51173
# [16]	validation_0-logloss:0.49285	validation_1-logloss:0.50462
# [17]	validation_0-logloss:0.48957	validation_1-logloss:0.50283
# [18]	validation_0-logloss:0.48181	validation_1-logloss:0.49681
# [19]	validation_0-logloss:0.47292	validation_1-logloss:0.48699
# [20]	validation_0-logloss:0.46570	validation_1-logloss:0.47974
# [21]	validation_0-logloss:0.45932	validation_1-logloss:0.47326
# [22]	validation_0-logloss:0.45210	validation_1-logloss:0.46566
# [23]	validation_0-logloss:0.44675	validation_1-logloss:0.46037
# [24]	validation_0-logloss:0.44438	validation_1-logloss:0.45899
# [25]	validation_0-logloss:0.44132	validation_1-logloss:0.45771
# [26]	validation_0-logloss:0.43482	validation_1-logloss:0.45250
# [27]	validation_0-logloss:0.43264	validation_1-logloss:0.45314
# [28]	validation_0-logloss:0.42829	validation_1-logloss:0.44931
# [29]	validation_0-logloss:0.42604	validation_1-logloss:0.44937
# [30]	validation_0-logloss:0.42420	validation_1-logloss:0.44868
# [31]	validation_0-logloss:0.41944	validation_1-logloss:0.44600
# [32]	validation_0-logloss:0.41508	validation_1-logloss:0.44293
# [33]	validation_0-logloss:0.41336	validation_1-logloss:0.44275
# [34]	validation_0-logloss:0.41135	validation_1-logloss:0.44230
# [35]	validation_0-logloss:0.40736	validation_1-logloss:0.44054
# [36]	validation_0-logloss:0.40355	validation_1-logloss:0.43843
# [37]	validation_0-logloss:0.39955	validation_1-logloss:0.43569
# [38]	validation_0-logloss:0.39646	validation_1-logloss:0.43327
# [39]	validation_0-logloss:0.39486	validation_1-logloss:0.43340
# [40]	validation_0-logloss:0.39332	validation_1-logloss:0.43392
# [41]	validation_0-logloss:0.39189	validation_1-logloss:0.43441
# [42]	validation_0-logloss:0.39078	validation_1-logloss:0.43496
# [43]	validation_0-logloss:0.38800	validation_1-logloss:0.43304
# [44]	validation_0-logloss:0.38512	validation_1-logloss:0.43077
# [45]	validation_0-logloss:0.38246	validation_1-logloss:0.42842
# [46]	validation_0-logloss:0.38117	validation_1-logloss:0.42905
# [47]	validation_0-logloss:0.37934	validation_1-logloss:0.42858
# [48]	validation_0-logloss:0.37717	validation_1-logloss:0.42731
# [49]	validation_0-logloss:0.37627	validation_1-logloss:0.42773
# [50]	validation_0-logloss:0.37538	validation_1-logloss:0.42856
# [51]	validation_0-logloss:0.37332	validation_1-logloss:0.42657
# [52]	validation_0-logloss:0.37132	validation_1-logloss:0.42501
# [53]	validation_0-logloss:0.36957	validation_1-logloss:0.42323
# [54]	validation_0-logloss:0.36782	validation_1-logloss:0.42327
# [55]	validation_0-logloss:0.36630	validation_1-logloss:0.42171
# [56]	validation_0-logloss:0.36516	validation_1-logloss:0.42177
# [57]	validation_0-logloss:0.36396	validation_1-logloss:0.42280
# [58]	validation_0-logloss:0.36261	validation_1-logloss:0.42151
# [59]	validation_0-logloss:0.36136	validation_1-logloss:0.42033
# [60]	validation_0-logloss:0.36000	validation_1-logloss:0.41872
# [61]	validation_0-logloss:0.35934	validation_1-logloss:0.41924
# [62]	validation_0-logloss:0.35798	validation_1-logloss:0.41908
# [63]	validation_0-logloss:0.35669	validation_1-logloss:0.41837
# [64]	validation_0-logloss:0.35570	validation_1-logloss:0.41746
# [65]	validation_0-logloss:0.35468	validation_1-logloss:0.41796
# [66]	validation_0-logloss:0.35360	validation_1-logloss:0.41848
# [67]	validation_0-logloss:0.35293	validation_1-logloss:0.41858
# [68]	validation_0-logloss:0.35225	validation_1-logloss:0.42032
# [69]	validation_0-logloss:0.35125	validation_1-logloss:0.41972
# [70]	validation_0-logloss:0.35074	validation_1-logloss:0.42105
# [71]	validation_0-logloss:0.34999	validation_1-logloss:0.42082
# [72]	validation_0-logloss:0.34952	validation_1-logloss:0.42120
# [73]	validation_0-logloss:0.34868	validation_1-logloss:0.42115
# [74]	validation_0-logloss:0.34780	validation_1-logloss:0.42057
# [75]	validation_0-logloss:0.34709	validation_1-logloss:0.41999
# [76]	validation_0-logloss:0.34641	validation_1-logloss:0.41951
# [77]	validation_0-logloss:0.34555	validation_1-logloss:0.42030
# [78]	validation_0-logloss:0.34486	validation_1-logloss:0.41974
# [79]	validation_0-logloss:0.34403	validation_1-logloss:0.41971
# [80]	validation_0-logloss:0.34333	validation_1-logloss:0.41923
# [81]	validation_0-logloss:0.34268	validation_1-logloss:0.41932
# [82]	validation_0-logloss:0.34209	validation_1-logloss:0.41941
# [83]	validation_0-logloss:0.34128	validation_1-logloss:0.41950
# [84]	validation_0-logloss:0.34078	validation_1-logloss:0.41891
# [85]	validation_0-logloss:0.34004	validation_1-logloss:0.41941
# [86]	validation_0-logloss:0.33940	validation_1-logloss:0.41924
# [87]	validation_0-logloss:0.33844	validation_1-logloss:0.42011
# [88]	validation_0-logloss:0.33809	validation_1-logloss:0.41995
# [89]	validation_0-logloss:0.33780	validation_1-logloss:0.41952
# [90]	validation_0-logloss:0.33744	validation_1-logloss:0.41939
# [91]	validation_0-logloss:0.33713	validation_1-logloss:0.41875
# [92]	validation_0-logloss:0.33687	validation_1-logloss:0.41825
# [93]	validation_0-logloss:0.33646	validation_1-logloss:0.41946
# [94]	validation_0-logloss:0.33605	validation_1-logloss:0.41961
# [0]	validation_0-logloss:0.64594	validation_1-logloss:0.63349
# [1]	validation_0-logloss:0.63523	validation_1-logloss:0.62531
# [2]	validation_0-logloss:0.61455	validation_1-logloss:0.60430
# [3]	validation_0-logloss:0.60800	validation_1-logloss:0.59836
# [4]	validation_0-logloss:0.60074	validation_1-logloss:0.59254
# [5]	validation_0-logloss:0.59192	validation_1-logloss:0.58593
# [6]	validation_0-logloss:0.58467	validation_1-logloss:0.57995
# [7]	validation_0-logloss:0.57684	validation_1-logloss:0.57640
# [8]	validation_0-logloss:0.57063	validation_1-logloss:0.57075
# [9]	validation_0-logloss:0.55331	validation_1-logloss:0.55493
# [10]	validation_0-logloss:0.54066	validation_1-logloss:0.54302
# [11]	validation_0-logloss:0.53492	validation_1-logloss:0.53987
# [12]	validation_0-logloss:0.52265	validation_1-logloss:0.52983
# [13]	validation_0-logloss:0.51728	validation_1-logloss:0.52840
# [14]	validation_0-logloss:0.51281	validation_1-logloss:0.52646
# [15]	validation_0-logloss:0.50162	validation_1-logloss:0.51706
# [16]	validation_0-logloss:0.49210	validation_1-logloss:0.50999
# [17]	validation_0-logloss:0.48994	validation_1-logloss:0.50861
# [18]	validation_0-logloss:0.48222	validation_1-logloss:0.50160
# [19]	validation_0-logloss:0.47270	validation_1-logloss:0.49279
# [20]	validation_0-logloss:0.46506	validation_1-logloss:0.48467
# [21]	validation_0-logloss:0.45840	validation_1-logloss:0.47811
# [22]	validation_0-logloss:0.45109	validation_1-logloss:0.47206
# [23]	validation_0-logloss:0.44555	validation_1-logloss:0.46638
# [24]	validation_0-logloss:0.44221	validation_1-logloss:0.46624
# [25]	validation_0-logloss:0.43950	validation_1-logloss:0.46576
# [26]	validation_0-logloss:0.43278	validation_1-logloss:0.46072
# [27]	validation_0-logloss:0.43102	validation_1-logloss:0.45887
# [28]	validation_0-logloss:0.42664	validation_1-logloss:0.45550
# [29]	validation_0-logloss:0.42400	validation_1-logloss:0.45608
# [30]	validation_0-logloss:0.42182	validation_1-logloss:0.45593
# [31]	validation_0-logloss:0.41738	validation_1-logloss:0.45403
# [32]	validation_0-logloss:0.41350	validation_1-logloss:0.45196
# [33]	validation_0-logloss:0.41186	validation_1-logloss:0.45072
# [34]	validation_0-logloss:0.40983	validation_1-logloss:0.45077
# [35]	validation_0-logloss:0.40602	validation_1-logloss:0.44803
# [36]	validation_0-logloss:0.40259	validation_1-logloss:0.44656
# [37]	validation_0-logloss:0.39891	validation_1-logloss:0.44428
# [38]	validation_0-logloss:0.39616	validation_1-logloss:0.44312
# [39]	validation_0-logloss:0.39456	validation_1-logloss:0.44325
# [40]	validation_0-logloss:0.39353	validation_1-logloss:0.44293
# [41]	validation_0-logloss:0.39220	validation_1-logloss:0.44259
# [42]	validation_0-logloss:0.39110	validation_1-logloss:0.44214
# [43]	validation_0-logloss:0.38872	validation_1-logloss:0.44124
# [44]	validation_0-logloss:0.38537	validation_1-logloss:0.43954
# [45]	validation_0-logloss:0.38237	validation_1-logloss:0.43806
# [46]	validation_0-logloss:0.38151	validation_1-logloss:0.43790
# [47]	validation_0-logloss:0.37972	validation_1-logloss:0.43636
# [48]	validation_0-logloss:0.37735	validation_1-logloss:0.43588
# [49]	validation_0-logloss:0.37661	validation_1-logloss:0.43582
# [50]	validation_0-logloss:0.37589	validation_1-logloss:0.43554
# [51]	validation_0-logloss:0.37368	validation_1-logloss:0.43394
# [52]	validation_0-logloss:0.37136	validation_1-logloss:0.43293
# [53]	validation_0-logloss:0.36949	validation_1-logloss:0.43227
# [54]	validation_0-logloss:0.36774	validation_1-logloss:0.43257
# [55]	validation_0-logloss:0.36611	validation_1-logloss:0.43209
# [56]	validation_0-logloss:0.36498	validation_1-logloss:0.43149
# [57]	validation_0-logloss:0.36374	validation_1-logloss:0.43158
# [58]	validation_0-logloss:0.36243	validation_1-logloss:0.43083
# [59]	validation_0-logloss:0.36106	validation_1-logloss:0.43001
# [60]	validation_0-logloss:0.35966	validation_1-logloss:0.42885
# [61]	validation_0-logloss:0.35907	validation_1-logloss:0.42819
# [62]	validation_0-logloss:0.35784	validation_1-logloss:0.42901
# [63]	validation_0-logloss:0.35676	validation_1-logloss:0.42811
# [64]	validation_0-logloss:0.35563	validation_1-logloss:0.42774
# [65]	validation_0-logloss:0.35454	validation_1-logloss:0.42782
# [66]	validation_0-logloss:0.35345	validation_1-logloss:0.42865
# [67]	validation_0-logloss:0.35244	validation_1-logloss:0.42888
# [68]	validation_0-logloss:0.35202	validation_1-logloss:0.42889
# [69]	validation_0-logloss:0.35109	validation_1-logloss:0.42852
# [70]	validation_0-logloss:0.35066	validation_1-logloss:0.42842
# [71]	validation_0-logloss:0.34972	validation_1-logloss:0.42871
# [72]	validation_0-logloss:0.34923	validation_1-logloss:0.42830
# [73]	validation_0-logloss:0.34835	validation_1-logloss:0.42816
# [74]	validation_0-logloss:0.34766	validation_1-logloss:0.42851
# [75]	validation_0-logloss:0.34681	validation_1-logloss:0.42837
# [76]	validation_0-logloss:0.34600	validation_1-logloss:0.42826
# [77]	validation_0-logloss:0.34516	validation_1-logloss:0.42899
# [78]	validation_0-logloss:0.34447	validation_1-logloss:0.42868
# [79]	validation_0-logloss:0.34388	validation_1-logloss:0.42870
# [80]	validation_0-logloss:0.34325	validation_1-logloss:0.42845
# [81]	validation_0-logloss:0.34236	validation_1-logloss:0.42907
# [82]	validation_0-logloss:0.34174	validation_1-logloss:0.42907
# [83]	validation_0-logloss:0.34087	validation_1-logloss:0.42962
# [84]	validation_0-logloss:0.34035	validation_1-logloss:0.42960
# [85]	validation_0-logloss:0.33951	validation_1-logloss:0.42973
# [86]	validation_0-logloss:0.33900	validation_1-logloss:0.42920
# [87]	validation_0-logloss:0.33840	validation_1-logloss:0.42935
# [88]	validation_0-logloss:0.33814	validation_1-logloss:0.42844
# [89]	validation_0-logloss:0.33765	validation_1-logloss:0.42800
# [90]	validation_0-logloss:0.33713	validation_1-logloss:0.42810
# [91]	validation_0-logloss:0.33691	validation_1-logloss:0.42729
# [92]	validation_0-logloss:0.33666	validation_1-logloss:0.42656
# [93]	validation_0-logloss:0.33635	validation_1-logloss:0.42581
# [94]	validation_0-logloss:0.33580	validation_1-logloss:0.42608
# [95]	validation_0-logloss:0.33508	validation_1-logloss:0.42670
# [96]	validation_0-logloss:0.33463	validation_1-logloss:0.42654
# [97]	validation_0-logloss:0.33391	validation_1-logloss:0.42670
# [98]	validation_0-logloss:0.33344	validation_1-logloss:0.42726
# [99]	validation_0-logloss:0.33278	validation_1-logloss:0.42731
# [0]	validation_0-logloss:0.64020	validation_1-logloss:0.65649
# [1]	validation_0-logloss:0.62791	validation_1-logloss:0.64890
# [2]	validation_0-logloss:0.60651	validation_1-logloss:0.63093
# [3]	validation_0-logloss:0.59825	validation_1-logloss:0.62580
# [4]	validation_0-logloss:0.59013	validation_1-logloss:0.61940
# [5]	validation_0-logloss:0.58094	validation_1-logloss:0.61542
# [6]	validation_0-logloss:0.57327	validation_1-logloss:0.60961
# [7]	validation_0-logloss:0.56639	validation_1-logloss:0.60630
# [8]	validation_0-logloss:0.55905	validation_1-logloss:0.60307
# [9]	validation_0-logloss:0.54201	validation_1-logloss:0.58949
# [10]	validation_0-logloss:0.52927	validation_1-logloss:0.57791
# [11]	validation_0-logloss:0.52352	validation_1-logloss:0.57550
# [12]	validation_0-logloss:0.51239	validation_1-logloss:0.56452
# [13]	validation_0-logloss:0.50772	validation_1-logloss:0.56215
# [14]	validation_0-logloss:0.50353	validation_1-logloss:0.55878
# [15]	validation_0-logloss:0.49323	validation_1-logloss:0.54835
# [16]	validation_0-logloss:0.48426	validation_1-logloss:0.54069
# [17]	validation_0-logloss:0.48118	validation_1-logloss:0.53961
# [18]	validation_0-logloss:0.47372	validation_1-logloss:0.53252
# [19]	validation_0-logloss:0.46372	validation_1-logloss:0.52563
# [20]	validation_0-logloss:0.45569	validation_1-logloss:0.52000
# [21]	validation_0-logloss:0.44877	validation_1-logloss:0.51546
# [22]	validation_0-logloss:0.44131	validation_1-logloss:0.50953
# [23]	validation_0-logloss:0.43552	validation_1-logloss:0.50598
# [24]	validation_0-logloss:0.43253	validation_1-logloss:0.50552
# [25]	validation_0-logloss:0.42999	validation_1-logloss:0.50423
# [26]	validation_0-logloss:0.42396	validation_1-logloss:0.49991
# [27]	validation_0-logloss:0.42225	validation_1-logloss:0.50010
# [28]	validation_0-logloss:0.41801	validation_1-logloss:0.49732
# [29]	validation_0-logloss:0.41575	validation_1-logloss:0.49728
# [30]	validation_0-logloss:0.41399	validation_1-logloss:0.49601
# [31]	validation_0-logloss:0.40996	validation_1-logloss:0.49182
# [32]	validation_0-logloss:0.40611	validation_1-logloss:0.48726
# [33]	validation_0-logloss:0.40409	validation_1-logloss:0.48830
# [34]	validation_0-logloss:0.40213	validation_1-logloss:0.48868
# [35]	validation_0-logloss:0.39873	validation_1-logloss:0.48542
# [36]	validation_0-logloss:0.39542	validation_1-logloss:0.48190
# [37]	validation_0-logloss:0.39145	validation_1-logloss:0.47897
# [38]	validation_0-logloss:0.38879	validation_1-logloss:0.47575
# [39]	validation_0-logloss:0.38768	validation_1-logloss:0.47574
# [40]	validation_0-logloss:0.38601	validation_1-logloss:0.47720
# [41]	validation_0-logloss:0.38454	validation_1-logloss:0.47865
# [42]	validation_0-logloss:0.38312	validation_1-logloss:0.48017
# [43]	validation_0-logloss:0.38073	validation_1-logloss:0.47736
# [44]	validation_0-logloss:0.37733	validation_1-logloss:0.47489
# [45]	validation_0-logloss:0.37421	validation_1-logloss:0.47328
# [46]	validation_0-logloss:0.37332	validation_1-logloss:0.47392
# [47]	validation_0-logloss:0.37166	validation_1-logloss:0.47256
# [48]	validation_0-logloss:0.36966	validation_1-logloss:0.47221
# [49]	validation_0-logloss:0.36855	validation_1-logloss:0.47384
# [50]	validation_0-logloss:0.36809	validation_1-logloss:0.47427
# [51]	validation_0-logloss:0.36592	validation_1-logloss:0.47364
# [52]	validation_0-logloss:0.36369	validation_1-logloss:0.47291
# [53]	validation_0-logloss:0.36151	validation_1-logloss:0.47189
# [54]	validation_0-logloss:0.35992	validation_1-logloss:0.47180
# [55]	validation_0-logloss:0.35807	validation_1-logloss:0.47114
# [56]	validation_0-logloss:0.35694	validation_1-logloss:0.47026
# [57]	validation_0-logloss:0.35603	validation_1-logloss:0.47041
# [58]	validation_0-logloss:0.35440	validation_1-logloss:0.46995
# [59]	validation_0-logloss:0.35297	validation_1-logloss:0.46970
# [60]	validation_0-logloss:0.35144	validation_1-logloss:0.46966
# [61]	validation_0-logloss:0.35085	validation_1-logloss:0.46952
# [62]	validation_0-logloss:0.34973	validation_1-logloss:0.47011
# [63]	validation_0-logloss:0.34843	validation_1-logloss:0.47054
# [64]	validation_0-logloss:0.34713	validation_1-logloss:0.47021
# [65]	validation_0-logloss:0.34631	validation_1-logloss:0.47025
# [66]	validation_0-logloss:0.34536	validation_1-logloss:0.47068
# [67]	validation_0-logloss:0.34423	validation_1-logloss:0.47116
# [68]	validation_0-logloss:0.34389	validation_1-logloss:0.47129
# [69]	validation_0-logloss:0.34280	validation_1-logloss:0.47220
# [70]	validation_0-logloss:0.34249	validation_1-logloss:0.47230
# [71]	validation_0-logloss:0.34168	validation_1-logloss:0.47309
# [72]	validation_0-logloss:0.34093	validation_1-logloss:0.47316
# [73]	validation_0-logloss:0.34030	validation_1-logloss:0.47292
# [74]	validation_0-logloss:0.33973	validation_1-logloss:0.47323
# [75]	validation_0-logloss:0.33875	validation_1-logloss:0.47350
# [76]	validation_0-logloss:0.33790	validation_1-logloss:0.47335
# [77]	validation_0-logloss:0.33714	validation_1-logloss:0.47391
# [78]	validation_0-logloss:0.33643	validation_1-logloss:0.47429
# [79]	validation_0-logloss:0.33589	validation_1-logloss:0.47474
# [80]	validation_0-logloss:0.33518	validation_1-logloss:0.47562
# [81]	validation_0-logloss:0.33448	validation_1-logloss:0.47568
# [82]	validation_0-logloss:0.33406	validation_1-logloss:0.47565
# [83]	validation_0-logloss:0.33322	validation_1-logloss:0.47530
# [84]	validation_0-logloss:0.33254	validation_1-logloss:0.47570
# [85]	validation_0-logloss:0.33168	validation_1-logloss:0.47606
# [86]	validation_0-logloss:0.33102	validation_1-logloss:0.47695
# [87]	validation_0-logloss:0.33039	validation_1-logloss:0.47719
# [88]	validation_0-logloss:0.32990	validation_1-logloss:0.47808
# [89]	validation_0-logloss:0.32942	validation_1-logloss:0.47885
# [90]	validation_0-logloss:0.32886	validation_1-logloss:0.47906
# [0]	validation_0-logloss:0.63520	validation_1-logloss:0.68069
# [1]	validation_0-logloss:0.62430	validation_1-logloss:0.67084
# [2]	validation_0-logloss:0.60412	validation_1-logloss:0.64908
# [3]	validation_0-logloss:0.59626	validation_1-logloss:0.64222
# [4]	validation_0-logloss:0.58807	validation_1-logloss:0.63484
# [5]	validation_0-logloss:0.57936	validation_1-logloss:0.62494
# [6]	validation_0-logloss:0.57179	validation_1-logloss:0.61909
# [7]	validation_0-logloss:0.56562	validation_1-logloss:0.61258
# [8]	validation_0-logloss:0.55878	validation_1-logloss:0.60468
# [9]	validation_0-logloss:0.54276	validation_1-logloss:0.58856
# [10]	validation_0-logloss:0.53024	validation_1-logloss:0.57535
# [11]	validation_0-logloss:0.52494	validation_1-logloss:0.57044
# [12]	validation_0-logloss:0.51407	validation_1-logloss:0.55846
# [13]	validation_0-logloss:0.50997	validation_1-logloss:0.55521
# [14]	validation_0-logloss:0.50554	validation_1-logloss:0.55303
# [15]	validation_0-logloss:0.49521	validation_1-logloss:0.54291
# [16]	validation_0-logloss:0.48683	validation_1-logloss:0.53384
# [17]	validation_0-logloss:0.48365	validation_1-logloss:0.53252
# [18]	validation_0-logloss:0.47635	validation_1-logloss:0.52490
# [19]	validation_0-logloss:0.46694	validation_1-logloss:0.51475
# [20]	validation_0-logloss:0.45926	validation_1-logloss:0.50754
# [21]	validation_0-logloss:0.45263	validation_1-logloss:0.50134
# [22]	validation_0-logloss:0.44500	validation_1-logloss:0.49423
# [23]	validation_0-logloss:0.43946	validation_1-logloss:0.48922
# [24]	validation_0-logloss:0.43717	validation_1-logloss:0.48699
# [25]	validation_0-logloss:0.43454	validation_1-logloss:0.48591
# [26]	validation_0-logloss:0.42858	validation_1-logloss:0.48017
# [27]	validation_0-logloss:0.42646	validation_1-logloss:0.48062
# [28]	validation_0-logloss:0.42219	validation_1-logloss:0.47717
# [29]	validation_0-logloss:0.42041	validation_1-logloss:0.47614
# [30]	validation_0-logloss:0.41877	validation_1-logloss:0.47441
# [31]	validation_0-logloss:0.41438	validation_1-logloss:0.46974
# [32]	validation_0-logloss:0.41046	validation_1-logloss:0.46579
# [33]	validation_0-logloss:0.40911	validation_1-logloss:0.46524
# [34]	validation_0-logloss:0.40730	validation_1-logloss:0.46462
# [35]	validation_0-logloss:0.40385	validation_1-logloss:0.46159
# [36]	validation_0-logloss:0.40045	validation_1-logloss:0.45821
# [37]	validation_0-logloss:0.39656	validation_1-logloss:0.45507
# [38]	validation_0-logloss:0.39360	validation_1-logloss:0.45221
# [39]	validation_0-logloss:0.39267	validation_1-logloss:0.45114
# [40]	validation_0-logloss:0.39141	validation_1-logloss:0.45068
# [41]	validation_0-logloss:0.39039	validation_1-logloss:0.45062
# [42]	validation_0-logloss:0.38928	validation_1-logloss:0.45029
# [43]	validation_0-logloss:0.38691	validation_1-logloss:0.44823
# [44]	validation_0-logloss:0.38351	validation_1-logloss:0.44538
# [45]	validation_0-logloss:0.38053	validation_1-logloss:0.44309
# [46]	validation_0-logloss:0.37985	validation_1-logloss:0.44293
# [47]	validation_0-logloss:0.37804	validation_1-logloss:0.44174
# [48]	validation_0-logloss:0.37584	validation_1-logloss:0.44007
# [49]	validation_0-logloss:0.37492	validation_1-logloss:0.43977
# [50]	validation_0-logloss:0.37425	validation_1-logloss:0.44090
# [51]	validation_0-logloss:0.37190	validation_1-logloss:0.43983
# [52]	validation_0-logloss:0.36952	validation_1-logloss:0.43819
# [53]	validation_0-logloss:0.36732	validation_1-logloss:0.43742
# [54]	validation_0-logloss:0.36550	validation_1-logloss:0.43613
# [55]	validation_0-logloss:0.36349	validation_1-logloss:0.43522
# [56]	validation_0-logloss:0.36239	validation_1-logloss:0.43483
# [57]	validation_0-logloss:0.36155	validation_1-logloss:0.43474
# [58]	validation_0-logloss:0.35969	validation_1-logloss:0.43449
# [59]	validation_0-logloss:0.35816	validation_1-logloss:0.43374
# [60]	validation_0-logloss:0.35644	validation_1-logloss:0.43400
# [61]	validation_0-logloss:0.35589	validation_1-logloss:0.43363
# [62]	validation_0-logloss:0.35445	validation_1-logloss:0.43333
# [63]	validation_0-logloss:0.35315	validation_1-logloss:0.43262
# [64]	validation_0-logloss:0.35197	validation_1-logloss:0.43296
# [65]	validation_0-logloss:0.35115	validation_1-logloss:0.43308
# [66]	validation_0-logloss:0.34995	validation_1-logloss:0.43271
# [67]	validation_0-logloss:0.34877	validation_1-logloss:0.43264
# [68]	validation_0-logloss:0.34837	validation_1-logloss:0.43317
# [69]	validation_0-logloss:0.34735	validation_1-logloss:0.43276
# [70]	validation_0-logloss:0.34698	validation_1-logloss:0.43331
# [71]	validation_0-logloss:0.34604	validation_1-logloss:0.43307
# [72]	validation_0-logloss:0.34566	validation_1-logloss:0.43304
# [73]	validation_0-logloss:0.34472	validation_1-logloss:0.43291
# [74]	validation_0-logloss:0.34397	validation_1-logloss:0.43333
# [75]	validation_0-logloss:0.34303	validation_1-logloss:0.43357
# [76]	validation_0-logloss:0.34213	validation_1-logloss:0.43347
# [77]	validation_0-logloss:0.34117	validation_1-logloss:0.43283
# [78]	validation_0-logloss:0.34032	validation_1-logloss:0.43278
# [79]	validation_0-logloss:0.33966	validation_1-logloss:0.43341
# [80]	validation_0-logloss:0.33890	validation_1-logloss:0.43334
# [81]	validation_0-logloss:0.33805	validation_1-logloss:0.43338
# [82]	validation_0-logloss:0.33742	validation_1-logloss:0.43366
# [83]	validation_0-logloss:0.33662	validation_1-logloss:0.43398
# [84]	validation_0-logloss:0.33603	validation_1-logloss:0.43444
# [85]	validation_0-logloss:0.33552	validation_1-logloss:0.43428
# [86]	validation_0-logloss:0.33485	validation_1-logloss:0.43481
# [87]	validation_0-logloss:0.33416	validation_1-logloss:0.43465
# [88]	validation_0-logloss:0.33377	validation_1-logloss:0.43486
# [89]	validation_0-logloss:0.33336	validation_1-logloss:0.43552
# [90]	validation_0-logloss:0.33290	validation_1-logloss:0.43646
# [91]	validation_0-logloss:0.33258	validation_1-logloss:0.43669
# [92]	validation_0-logloss:0.33229	validation_1-logloss:0.43693
# [0]	validation_0-logloss:0.61373	validation_1-logloss:0.61898
# [1]	validation_0-logloss:0.59494	validation_1-logloss:0.61112
# [2]	validation_0-logloss:0.55899	validation_1-logloss:0.58447
# [3]	validation_0-logloss:0.54504	validation_1-logloss:0.57823
# [4]	validation_0-logloss:0.53367	validation_1-logloss:0.57240
# [5]	validation_0-logloss:0.52541	validation_1-logloss:0.56759
# [6]	validation_0-logloss:0.51699	validation_1-logloss:0.56183
# [7]	validation_0-logloss:0.50619	validation_1-logloss:0.55575
# [8]	validation_0-logloss:0.49956	validation_1-logloss:0.55442
# [9]	validation_0-logloss:0.47792	validation_1-logloss:0.53936
# [10]	validation_0-logloss:0.46222	validation_1-logloss:0.52937
# [11]	validation_0-logloss:0.45592	validation_1-logloss:0.52456
# [12]	validation_0-logloss:0.44178	validation_1-logloss:0.51521
# [13]	validation_0-logloss:0.43806	validation_1-logloss:0.51219
# [14]	validation_0-logloss:0.43567	validation_1-logloss:0.51077
# [15]	validation_0-logloss:0.43156	validation_1-logloss:0.50876
# [16]	validation_0-logloss:0.42915	validation_1-logloss:0.50645
# [17]	validation_0-logloss:0.42632	validation_1-logloss:0.50520
# [18]	validation_0-logloss:0.42475	validation_1-logloss:0.50513
# [19]	validation_0-logloss:0.41186	validation_1-logloss:0.49469
# [20]	validation_0-logloss:0.40986	validation_1-logloss:0.49189
# [21]	validation_0-logloss:0.40131	validation_1-logloss:0.48602
# [22]	validation_0-logloss:0.39316	validation_1-logloss:0.48059
# [23]	validation_0-logloss:0.38766	validation_1-logloss:0.47705
# [24]	validation_0-logloss:0.38594	validation_1-logloss:0.47441
# [25]	validation_0-logloss:0.38422	validation_1-logloss:0.47382
# [26]	validation_0-logloss:0.37944	validation_1-logloss:0.47191
# [27]	validation_0-logloss:0.37800	validation_1-logloss:0.47196
# [28]	validation_0-logloss:0.37492	validation_1-logloss:0.47105
# [29]	validation_0-logloss:0.37400	validation_1-logloss:0.47209
# [30]	validation_0-logloss:0.37288	validation_1-logloss:0.47117
# [31]	validation_0-logloss:0.36962	validation_1-logloss:0.47056
# [32]	validation_0-logloss:0.36698	validation_1-logloss:0.46892
# [33]	validation_0-logloss:0.36577	validation_1-logloss:0.46734
# [34]	validation_0-logloss:0.36451	validation_1-logloss:0.46654
# [35]	validation_0-logloss:0.36259	validation_1-logloss:0.46593
# [36]	validation_0-logloss:0.36054	validation_1-logloss:0.46595
# [37]	validation_0-logloss:0.35749	validation_1-logloss:0.46254
# [38]	validation_0-logloss:0.35659	validation_1-logloss:0.46200
# [39]	validation_0-logloss:0.35552	validation_1-logloss:0.46173
# [40]	validation_0-logloss:0.35435	validation_1-logloss:0.45925
# [41]	validation_0-logloss:0.35324	validation_1-logloss:0.45886
# [42]	validation_0-logloss:0.35242	validation_1-logloss:0.45939
# [43]	validation_0-logloss:0.35087	validation_1-logloss:0.46014
# [44]	validation_0-logloss:0.34858	validation_1-logloss:0.45578
# [45]	validation_0-logloss:0.34740	validation_1-logloss:0.45274
# [46]	validation_0-logloss:0.34700	validation_1-logloss:0.45281
# [47]	validation_0-logloss:0.34617	validation_1-logloss:0.45257
# [48]	validation_0-logloss:0.34535	validation_1-logloss:0.45362
# [49]	validation_0-logloss:0.34452	validation_1-logloss:0.45308
# [50]	validation_0-logloss:0.34417	validation_1-logloss:0.45295
# [51]	validation_0-logloss:0.34378	validation_1-logloss:0.45283
# [52]	validation_0-logloss:0.34231	validation_1-logloss:0.44990
# [53]	validation_0-logloss:0.34097	validation_1-logloss:0.44921
# [54]	validation_0-logloss:0.33998	validation_1-logloss:0.44866
# [55]	validation_0-logloss:0.33879	validation_1-logloss:0.44776
# [56]	validation_0-logloss:0.33829	validation_1-logloss:0.44778
# [57]	validation_0-logloss:0.33742	validation_1-logloss:0.44804
# [58]	validation_0-logloss:0.33684	validation_1-logloss:0.44891
# [59]	validation_0-logloss:0.33585	validation_1-logloss:0.44680
# [60]	validation_0-logloss:0.33511	validation_1-logloss:0.44631
# [61]	validation_0-logloss:0.33477	validation_1-logloss:0.44706
# [62]	validation_0-logloss:0.33407	validation_1-logloss:0.44708
# [63]	validation_0-logloss:0.33371	validation_1-logloss:0.44676
# [64]	validation_0-logloss:0.33330	validation_1-logloss:0.44628
# [65]	validation_0-logloss:0.33271	validation_1-logloss:0.44584
# [66]	validation_0-logloss:0.33237	validation_1-logloss:0.44627
# [67]	validation_0-logloss:0.33207	validation_1-logloss:0.44709
# [68]	validation_0-logloss:0.33190	validation_1-logloss:0.44768
# [69]	validation_0-logloss:0.33135	validation_1-logloss:0.44678
# [70]	validation_0-logloss:0.33103	validation_1-logloss:0.44818
# [71]	validation_0-logloss:0.33064	validation_1-logloss:0.45010
# [72]	validation_0-logloss:0.33032	validation_1-logloss:0.45147
# [73]	validation_0-logloss:0.32988	validation_1-logloss:0.45223
# [74]	validation_0-logloss:0.32942	validation_1-logloss:0.45429
# [75]	validation_0-logloss:0.32917	validation_1-logloss:0.45449
# [76]	validation_0-logloss:0.32890	validation_1-logloss:0.45530
# [77]	validation_0-logloss:0.32837	validation_1-logloss:0.45503
# [78]	validation_0-logloss:0.32797	validation_1-logloss:0.45460
# [79]	validation_0-logloss:0.32778	validation_1-logloss:0.45462
# [80]	validation_0-logloss:0.32735	validation_1-logloss:0.45380
# [81]	validation_0-logloss:0.32682	validation_1-logloss:0.45295
# [82]	validation_0-logloss:0.32635	validation_1-logloss:0.45475
# [83]	validation_0-logloss:0.32596	validation_1-logloss:0.45414
# [84]	validation_0-logloss:0.32575	validation_1-logloss:0.45406
# [85]	validation_0-logloss:0.32553	validation_1-logloss:0.45380
# [86]	validation_0-logloss:0.32537	validation_1-logloss:0.45444
# [87]	validation_0-logloss:0.32498	validation_1-logloss:0.45530
# [88]	validation_0-logloss:0.32488	validation_1-logloss:0.45521
# [89]	validation_0-logloss:0.32443	validation_1-logloss:0.45695
# [90]	validation_0-logloss:0.32395	validation_1-logloss:0.45602
# [91]	validation_0-logloss:0.32379	validation_1-logloss:0.45616
# [92]	validation_0-logloss:0.32367	validation_1-logloss:0.45630
# [93]	validation_0-logloss:0.32344	validation_1-logloss:0.45709
# [94]	validation_0-logloss:0.32315	validation_1-logloss:0.45660
# [95]	validation_0-logloss:0.32280	validation_1-logloss:0.45680
# [0]	validation_0-logloss:0.62097	validation_1-logloss:0.59887
# [1]	validation_0-logloss:0.60444	validation_1-logloss:0.58564
# [2]	validation_0-logloss:0.57019	validation_1-logloss:0.55264
# [3]	validation_0-logloss:0.55526	validation_1-logloss:0.54279
# [4]	validation_0-logloss:0.54490	validation_1-logloss:0.53400
# [5]	validation_0-logloss:0.53615	validation_1-logloss:0.52968
# [6]	validation_0-logloss:0.52699	validation_1-logloss:0.52541
# [7]	validation_0-logloss:0.51764	validation_1-logloss:0.51871
# [8]	validation_0-logloss:0.51071	validation_1-logloss:0.51579
# [9]	validation_0-logloss:0.49055	validation_1-logloss:0.49738
# [10]	validation_0-logloss:0.47504	validation_1-logloss:0.48317
# [11]	validation_0-logloss:0.46938	validation_1-logloss:0.47906
# [12]	validation_0-logloss:0.45538	validation_1-logloss:0.46765
# [13]	validation_0-logloss:0.45045	validation_1-logloss:0.46637
# [14]	validation_0-logloss:0.44743	validation_1-logloss:0.46752
# [15]	validation_0-logloss:0.44311	validation_1-logloss:0.46593
# [16]	validation_0-logloss:0.43980	validation_1-logloss:0.46790
# ...
# [16]	validation_0-logloss:0.40750	validation_1-logloss:0.48632
# [17]	validation_0-logloss:0.40499	validation_1-logloss:0.48578
# [18]	validation_0-logloss:0.39792	validation_1-logloss:0.48265
# [19]	validation_0-logloss:0.38939	validation_1-logloss:0.47634
# [20]	validation_0-logloss:0.38301	validation_1-logloss:0.47069
# [21]	validation_0-logloss:0.37765	validation_1-logloss:0.46807
# [22]	validation_0-logloss:0.37237	validation_1-logloss:0.46559
# [23]	validation_0-logloss:0.36888	validation_1-logloss:0.46278
# [24]	validation_0-logloss:0.36598	validation_1-logloss:0.46084
# [25]	validation_0-logloss:0.36343	validation_1-logloss:0.45920
# [26]	validation_0-logloss:0.35915	validation_1-logloss:0.45348
# [27]	validation_0-logloss:0.35791	validation_1-logloss:0.45398
# [28]	validation_0-logloss:0.35472	validation_1-logloss:0.45260
# [29]	validation_0-logloss:0.35315	validation_1-logloss:0.45235
# [30]	validation_0-logloss:0.35143	validation_1-logloss:0.45247
# [31]	validation_0-logloss:0.34907	validation_1-logloss:0.45099
# [32]	validation_0-logloss:0.34666	validation_1-logloss:0.45087
# [33]	validation_0-logloss:0.34564	validation_1-logloss:0.44943
# [34]	validation_0-logloss:0.34453	validation_1-logloss:0.44880
# [35]	validation_0-logloss:0.34254	validation_1-logloss:0.44955
# [36]	validation_0-logloss:0.34109	validation_1-logloss:0.44896
# [37]	validation_0-logloss:0.33877	validation_1-logloss:0.44779
# [38]	validation_0-logloss:0.33704	validation_1-logloss:0.44836
# [39]	validation_0-logloss:0.33612	validation_1-logloss:0.44824
# [40]	validation_0-logloss:0.33476	validation_1-logloss:0.44778
# [41]	validation_0-logloss:0.33350	validation_1-logloss:0.44635
# [42]	validation_0-logloss:0.33238	validation_1-logloss:0.44579
# [43]	validation_0-logloss:0.33099	validation_1-logloss:0.44670
# [44]	validation_0-logloss:0.32896	validation_1-logloss:0.44478
# [45]	validation_0-logloss:0.32769	validation_1-logloss:0.44247
# [46]	validation_0-logloss:0.32709	validation_1-logloss:0.44309
# [47]	validation_0-logloss:0.32623	validation_1-logloss:0.44355
# [48]	validation_0-logloss:0.32488	validation_1-logloss:0.44311
# [49]	validation_0-logloss:0.32393	validation_1-logloss:0.44316
# [50]	validation_0-logloss:0.32322	validation_1-logloss:0.44467
# [51]	validation_0-logloss:0.32214	validation_1-logloss:0.44279
# [52]	validation_0-logloss:0.32122	validation_1-logloss:0.44112
# [53]	validation_0-logloss:0.32034	validation_1-logloss:0.44199
# [54]	validation_0-logloss:0.31936	validation_1-logloss:0.44145
# [55]	validation_0-logloss:0.31863	validation_1-logloss:0.44303
# [56]	validation_0-logloss:0.31817	validation_1-logloss:0.44469
# [57]	validation_0-logloss:0.31738	validation_1-logloss:0.44390
# [58]	validation_0-logloss:0.31679	validation_1-logloss:0.44492
# [59]	validation_0-logloss:0.31603	validation_1-logloss:0.44525
# [60]	validation_0-logloss:0.31534	validation_1-logloss:0.44541
# [61]	validation_0-logloss:0.31475	validation_1-logloss:0.44666
# [62]	validation_0-logloss:0.31376	validation_1-logloss:0.44568
# [63]	validation_0-logloss:0.31334	validation_1-logloss:0.44606
# [64]	validation_0-logloss:0.31289	validation_1-logloss:0.44664
# [65]	validation_0-logloss:0.31212	validation_1-logloss:0.44630
# [66]	validation_0-logloss:0.31140	validation_1-logloss:0.44683
# [67]	validation_0-logloss:0.31075	validation_1-logloss:0.44692
# [68]	validation_0-logloss:0.31021	validation_1-logloss:0.44692
# [69]	validation_0-logloss:0.30970	validation_1-logloss:0.44712
# [70]	validation_0-logloss:0.30940	validation_1-logloss:0.44761
# [71]	validation_0-logloss:0.30883	validation_1-logloss:0.44770
# [72]	validation_0-logloss:0.30820	validation_1-logloss:0.44882
# [73]	validation_0-logloss:0.30769	validation_1-logloss:0.44911
# [74]	validation_0-logloss:0.30728	validation_1-logloss:0.44900
# [75]	validation_0-logloss:0.30685	validation_1-logloss:0.44797
# [76]	validation_0-logloss:0.30659	validation_1-logloss:0.44848
# [77]	validation_0-logloss:0.30578	validation_1-logloss:0.44793
# [78]	validation_0-logloss:0.30528	validation_1-logloss:0.44795
# [79]	validation_0-logloss:0.30468	validation_1-logloss:0.44930
# [80]	validation_0-logloss:0.30406	validation_1-logloss:0.45038
# [81]	validation_0-logloss:0.30358	validation_1-logloss:0.45146
# [0]	validation_0-logloss:0.62598	validation_1-logloss:0.60365
# [1]	validation_0-logloss:0.60682	validation_1-logloss:0.59060
# [2]	validation_0-logloss:0.57079	validation_1-logloss:0.55503
# [3]	validation_0-logloss:0.55594	validation_1-logloss:0.54823
# [4]	validation_0-logloss:0.54338	validation_1-logloss:0.53995
# [5]	validation_0-logloss:0.53245	validation_1-logloss:0.53256
# [6]	validation_0-logloss:0.52102	validation_1-logloss:0.52820
# [7]	validation_0-logloss:0.51258	validation_1-logloss:0.52199
# [8]	validation_0-logloss:0.50560	validation_1-logloss:0.51827
# [9]	validation_0-logloss:0.48284	validation_1-logloss:0.49553
# [10]	validation_0-logloss:0.46607	validation_1-logloss:0.48249
# [11]	validation_0-logloss:0.46016	validation_1-logloss:0.47954
# [12]	validation_0-logloss:0.44586	validation_1-logloss:0.46872
# [13]	validation_0-logloss:0.44051	validation_1-logloss:0.46999
# [14]	validation_0-logloss:0.43574	validation_1-logloss:0.46903
# [15]	validation_0-logloss:0.42406	validation_1-logloss:0.45780
# [16]	validation_0-logloss:0.41485	validation_1-logloss:0.45140
# [17]	validation_0-logloss:0.41211	validation_1-logloss:0.45044
# [18]	validation_0-logloss:0.40558	validation_1-logloss:0.44581
# [19]	validation_0-logloss:0.39700	validation_1-logloss:0.43688
# [20]	validation_0-logloss:0.39115	validation_1-logloss:0.42982
# [21]	validation_0-logloss:0.38673	validation_1-logloss:0.42287
# [22]	validation_0-logloss:0.38158	validation_1-logloss:0.41825
# [23]	validation_0-logloss:0.37846	validation_1-logloss:0.41307
# [24]	validation_0-logloss:0.37616	validation_1-logloss:0.41317
# [25]	validation_0-logloss:0.37349	validation_1-logloss:0.41424
# [26]	validation_0-logloss:0.36955	validation_1-logloss:0.41172
# [27]	validation_0-logloss:0.36773	validation_1-logloss:0.41402
# [28]	validation_0-logloss:0.36470	validation_1-logloss:0.41252
# [29]	validation_0-logloss:0.36261	validation_1-logloss:0.41418
# [30]	validation_0-logloss:0.36095	validation_1-logloss:0.41572
# [31]	validation_0-logloss:0.35808	validation_1-logloss:0.41499
# [32]	validation_0-logloss:0.35548	validation_1-logloss:0.41464
# [33]	validation_0-logloss:0.35418	validation_1-logloss:0.41696
# [34]	validation_0-logloss:0.35224	validation_1-logloss:0.42023
# [35]	validation_0-logloss:0.35011	validation_1-logloss:0.41964
# [36]	validation_0-logloss:0.34849	validation_1-logloss:0.41923
# [37]	validation_0-logloss:0.34667	validation_1-logloss:0.41861
# [38]	validation_0-logloss:0.34521	validation_1-logloss:0.41830
# [39]	validation_0-logloss:0.34407	validation_1-logloss:0.41982
# [40]	validation_0-logloss:0.34248	validation_1-logloss:0.42142
# [41]	validation_0-logloss:0.34135	validation_1-logloss:0.42360
# [42]	validation_0-logloss:0.34051	validation_1-logloss:0.42371
# [43]	validation_0-logloss:0.33922	validation_1-logloss:0.42361
# [44]	validation_0-logloss:0.33692	validation_1-logloss:0.42302
# [45]	validation_0-logloss:0.33574	validation_1-logloss:0.42237
# [46]	validation_0-logloss:0.33505	validation_1-logloss:0.42396
# [47]	validation_0-logloss:0.33429	validation_1-logloss:0.42416
# [48]	validation_0-logloss:0.33292	validation_1-logloss:0.42382
# [49]	validation_0-logloss:0.33198	validation_1-logloss:0.42445
# [50]	validation_0-logloss:0.33110	validation_1-logloss:0.42739
# [51]	validation_0-logloss:0.33009	validation_1-logloss:0.42702
# [52]	validation_0-logloss:0.32893	validation_1-logloss:0.42720
# [53]	validation_0-logloss:0.32816	validation_1-logloss:0.42559
# [54]	validation_0-logloss:0.32683	validation_1-logloss:0.42639
# [55]	validation_0-logloss:0.32608	validation_1-logloss:0.42445
# [56]	validation_0-logloss:0.32548	validation_1-logloss:0.42623
# [0]	validation_0-logloss:0.62273	validation_1-logloss:0.61145
# [1]	validation_0-logloss:0.60265	validation_1-logloss:0.59792
# [2]	validation_0-logloss:0.56673	validation_1-logloss:0.56167
# [3]	validation_0-logloss:0.55669	validation_1-logloss:0.55262
# [4]	validation_0-logloss:0.54707	validation_1-logloss:0.54516
# [5]	validation_0-logloss:0.53556	validation_1-logloss:0.53480
# [6]	validation_0-logloss:0.52536	validation_1-logloss:0.52780
# [7]	validation_0-logloss:0.51512	validation_1-logloss:0.52533
# [8]	validation_0-logloss:0.50768	validation_1-logloss:0.51979
# [9]	validation_0-logloss:0.48301	validation_1-logloss:0.49771
# [10]	validation_0-logloss:0.46696	validation_1-logloss:0.48258
# [11]	validation_0-logloss:0.46136	validation_1-logloss:0.48177
# [12]	validation_0-logloss:0.44627	validation_1-logloss:0.47260
# [13]	validation_0-logloss:0.44081	validation_1-logloss:0.47251
# [14]	validation_0-logloss:0.43650	validation_1-logloss:0.47190
# [15]	validation_0-logloss:0.42506	validation_1-logloss:0.46365
# [16]	validation_0-logloss:0.41538	validation_1-logloss:0.45797
# [17]	validation_0-logloss:0.41358	validation_1-logloss:0.45671
# [18]	validation_0-logloss:0.40666	validation_1-logloss:0.45076
# [19]	validation_0-logloss:0.39864	validation_1-logloss:0.44345
# [20]	validation_0-logloss:0.39191	validation_1-logloss:0.43700
# [21]	validation_0-logloss:0.38699	validation_1-logloss:0.43145
# [22]	validation_0-logloss:0.38194	validation_1-logloss:0.42729
# [23]	validation_0-logloss:0.37847	validation_1-logloss:0.42335
# [24]	validation_0-logloss:0.37526	validation_1-logloss:0.42320
# [25]	validation_0-logloss:0.37228	validation_1-logloss:0.42441
# [26]	validation_0-logloss:0.36725	validation_1-logloss:0.42334
# [27]	validation_0-logloss:0.36592	validation_1-logloss:0.42260
# [28]	validation_0-logloss:0.36317	validation_1-logloss:0.42228
# [29]	validation_0-logloss:0.36079	validation_1-logloss:0.42358
# [30]	validation_0-logloss:0.35877	validation_1-logloss:0.42423
# [31]	validation_0-logloss:0.35602	validation_1-logloss:0.42477
# [32]	validation_0-logloss:0.35380	validation_1-logloss:0.42449
# [33]	validation_0-logloss:0.35180	validation_1-logloss:0.42572
# [34]	validation_0-logloss:0.35015	validation_1-logloss:0.42629
# [35]	validation_0-logloss:0.34795	validation_1-logloss:0.42583
# [36]	validation_0-logloss:0.34629	validation_1-logloss:0.42694
# [37]	validation_0-logloss:0.34448	validation_1-logloss:0.42690
# [38]	validation_0-logloss:0.34290	validation_1-logloss:0.42739
# [39]	validation_0-logloss:0.34165	validation_1-logloss:0.42845
# [40]	validation_0-logloss:0.34032	validation_1-logloss:0.42884
# [41]	validation_0-logloss:0.33930	validation_1-logloss:0.42874
# [42]	validation_0-logloss:0.33846	validation_1-logloss:0.42910
# [43]	validation_0-logloss:0.33713	validation_1-logloss:0.43042
# [44]	validation_0-logloss:0.33476	validation_1-logloss:0.42961
# [45]	validation_0-logloss:0.33317	validation_1-logloss:0.42957
# [46]	validation_0-logloss:0.33252	validation_1-logloss:0.42938
# [47]	validation_0-logloss:0.33163	validation_1-logloss:0.42962
# [48]	validation_0-logloss:0.32949	validation_1-logloss:0.43281
# [49]	validation_0-logloss:0.32832	validation_1-logloss:0.43322
# [50]	validation_0-logloss:0.32771	validation_1-logloss:0.43306
# [51]	validation_0-logloss:0.32645	validation_1-logloss:0.43350
# [52]	validation_0-logloss:0.32532	validation_1-logloss:0.43265
# [53]	validation_0-logloss:0.32446	validation_1-logloss:0.43216
# [54]	validation_0-logloss:0.32332	validation_1-logloss:0.43278
# [55]	validation_0-logloss:0.32248	validation_1-logloss:0.43160
# [56]	validation_0-logloss:0.32210	validation_1-logloss:0.43151
# [57]	validation_0-logloss:0.32138	validation_1-logloss:0.43149
# [58]	validation_0-logloss:0.32078	validation_1-logloss:0.43026
# [0]	validation_0-logloss:0.61708	validation_1-logloss:0.63450
# [1]	validation_0-logloss:0.59410	validation_1-logloss:0.62103
# [2]	validation_0-logloss:0.55720	validation_1-logloss:0.59093
# [3]	validation_0-logloss:0.54441	validation_1-logloss:0.58381
# [4]	validation_0-logloss:0.53288	validation_1-logloss:0.57611
# [5]	validation_0-logloss:0.51954	validation_1-logloss:0.57179
# [6]	validation_0-logloss:0.50984	validation_1-logloss:0.56555
# [7]	validation_0-logloss:0.50135	validation_1-logloss:0.56422
# [8]	validation_0-logloss:0.49357	validation_1-logloss:0.56181
# [9]	validation_0-logloss:0.47061	validation_1-logloss:0.54404
# [10]	validation_0-logloss:0.45468	validation_1-logloss:0.52982
# [11]	validation_0-logloss:0.44904	validation_1-logloss:0.53012
# [12]	validation_0-logloss:0.43594	validation_1-logloss:0.51825
# [13]	validation_0-logloss:0.43096	validation_1-logloss:0.51825
#  20%|█▌      | 10/50 [00:12<00:44,  1.10s/trial, best loss: -0.8638215099017964]

# %%
# n_estimators를 500증가 후 최적으로 찾은 하이퍼 파라미터를 기반으로 학습과 예측 수행.
xgb_clf = XGBClassifier(n_estimators=500, learning_rate=round(best['learning_rate'], 5),
                        max_depth=int(best['max_depth']), min_child_weight=int(best['min_child_weight']), 
                        colsample_bytree=round(best['colsample_bytree'], 5) 
                       )

# evaluation metric을 auc로, early stopping은 100 으로 설정하고 학습 수행. 
xgb_clf.fit(X_tr, y_tr, early_stopping_rounds=100, 
            eval_metric="auc",eval_set=[(X_tr, y_tr), (X_val, y_val)])

xgb_roc_score = roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:,1])
print('ROC AUC: {0:.4f}'.format(xgb_roc_score))
# Out:
# [0]	validation_0-auc:0.84274	validation_1-auc:0.81030
# [1]	validation_0-auc:0.87215	validation_1-auc:0.79074
# [2]	validation_0-auc:0.87881	validation_1-auc:0.82529
# [3]	validation_0-auc:0.87731	validation_1-auc:0.82725
# [4]	validation_0-auc:0.87392	validation_1-auc:0.83703
# [5]	validation_0-auc:0.87391	validation_1-auc:0.82203
# [6]	validation_0-auc:0.87640	validation_1-auc:0.78553
# [7]	validation_0-auc:0.87739	validation_1-auc:0.76597
# [8]	validation_0-auc:0.87585	validation_1-auc:0.75293
# [9]	validation_0-auc:0.88868	validation_1-auc:0.75684
# [10]	validation_0-auc:0.89293	validation_1-auc:0.75880
# [11]	validation_0-auc:0.89169	validation_1-auc:0.75880
# [12]	validation_0-auc:0.89606	validation_1-auc:0.76141
# [13]	validation_0-auc:0.89683	validation_1-auc:0.75489
# [14]	validation_0-auc:0.89631	validation_1-auc:0.75098
# [15]	validation_0-auc:0.89865	validation_1-auc:0.75489
# [16]	validation_0-auc:0.90165	validation_1-auc:0.74967
# [17]	validation_0-auc:0.90152	validation_1-auc:0.75228
# [18]	validation_0-auc:0.90174	validation_1-auc:0.75228
# [19]	validation_0-auc:0.90269	validation_1-auc:0.74576
# [20]	validation_0-auc:0.90385	validation_1-auc:0.74576
# [21]	validation_0-auc:0.90364	validation_1-auc:0.74576
# [22]	validation_0-auc:0.90470	validation_1-auc:0.74055
# [23]	validation_0-auc:0.90515	validation_1-auc:0.73924
# [24]	validation_0-auc:0.90710	validation_1-auc:0.74316
# [25]	validation_0-auc:0.90822	validation_1-auc:0.74707
# [26]	validation_0-auc:0.90880	validation_1-auc:0.74576
# [27]	validation_0-auc:0.90900	validation_1-auc:0.74707
# [28]	validation_0-auc:0.90970	validation_1-auc:0.74967
# [29]	validation_0-auc:0.91072	validation_1-auc:0.74837
# [30]	validation_0-auc:0.91146	validation_1-auc:0.74837
# [31]	validation_0-auc:0.91156	validation_1-auc:0.74967
# [32]	validation_0-auc:0.91165	validation_1-auc:0.74837
# [33]	validation_0-auc:0.91289	validation_1-auc:0.74707
# [34]	validation_0-auc:0.91351	validation_1-auc:0.74576
# [35]	validation_0-auc:0.91379	validation_1-auc:0.74316
# [36]	validation_0-auc:0.91427	validation_1-auc:0.74316
# [37]	validation_0-auc:0.91441	validation_1-auc:0.74316
# [38]	validation_0-auc:0.91494	validation_1-auc:0.73794
# [39]	validation_0-auc:0.91586	validation_1-auc:0.74185
# [40]	validation_0-auc:0.91631	validation_1-auc:0.74185
# [41]	validation_0-auc:0.91717	validation_1-auc:0.74185
# [42]	validation_0-auc:0.91754	validation_1-auc:0.74185
# [43]	validation_0-auc:0.91779	validation_1-auc:0.74185
# [44]	validation_0-auc:0.91835	validation_1-auc:0.74185
# [45]	validation_0-auc:0.91838	validation_1-auc:0.74316
# [46]	validation_0-auc:0.91841	validation_1-auc:0.74185
# [47]	validation_0-auc:0.91841	validation_1-auc:0.74185
# [48]	validation_0-auc:0.91862	validation_1-auc:0.74185
# [49]	validation_0-auc:0.91898	validation_1-auc:0.74185
# [50]	validation_0-auc:0.91956	validation_1-auc:0.74185
# [51]	validation_0-auc:0.91965	validation_1-auc:0.74446
# /opt/homebrew/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [52]	validation_0-auc:0.91996	validation_1-auc:0.75228
# [53]	validation_0-auc:0.92013	validation_1-auc:0.74837
# [54]	validation_0-auc:0.92012	validation_1-auc:0.74316
# [55]	validation_0-auc:0.92025	validation_1-auc:0.74446
# [56]	validation_0-auc:0.92029	validation_1-auc:0.74446
# [57]	validation_0-auc:0.92018	validation_1-auc:0.74446
# [58]	validation_0-auc:0.92044	validation_1-auc:0.74316
# [59]	validation_0-auc:0.92075	validation_1-auc:0.74316
# [60]	validation_0-auc:0.92069	validation_1-auc:0.74316
# [61]	validation_0-auc:0.92095	validation_1-auc:0.74316
# [62]	validation_0-auc:0.92064	validation_1-auc:0.74446
# [63]	validation_0-auc:0.92091	validation_1-auc:0.74446
# [64]	validation_0-auc:0.92094	validation_1-auc:0.74316
# [65]	validation_0-auc:0.92152	validation_1-auc:0.74707
# [66]	validation_0-auc:0.92181	validation_1-auc:0.74707
# [67]	validation_0-auc:0.92231	validation_1-auc:0.74837
# [68]	validation_0-auc:0.92285	validation_1-auc:0.74837
# [69]	validation_0-auc:0.92263	validation_1-auc:0.74837
# [70]	validation_0-auc:0.92301	validation_1-auc:0.74707
# [71]	validation_0-auc:0.92277	validation_1-auc:0.74837
# [72]	validation_0-auc:0.92317	validation_1-auc:0.75228
# [73]	validation_0-auc:0.92355	validation_1-auc:0.75228
# [74]	validation_0-auc:0.92366	validation_1-auc:0.75228
# [75]	validation_0-auc:0.92365	validation_1-auc:0.74837
# [76]	validation_0-auc:0.92371	validation_1-auc:0.75228
# [77]	validation_0-auc:0.92407	validation_1-auc:0.75098
# [78]	validation_0-auc:0.92441	validation_1-auc:0.74707
# [79]	validation_0-auc:0.92459	validation_1-auc:0.74707
# [80]	validation_0-auc:0.92457	validation_1-auc:0.74707
# [81]	validation_0-auc:0.92492	validation_1-auc:0.74837
# [82]	validation_0-auc:0.92516	validation_1-auc:0.74837
# [83]	validation_0-auc:0.92512	validation_1-auc:0.74967
# [84]	validation_0-auc:0.92503	validation_1-auc:0.75098
# [85]	validation_0-auc:0.92562	validation_1-auc:0.74967
# [86]	validation_0-auc:0.92568	validation_1-auc:0.75359
# [87]	validation_0-auc:0.92594	validation_1-auc:0.75228
# [88]	validation_0-auc:0.92603	validation_1-auc:0.74837
# [89]	validation_0-auc:0.92611	validation_1-auc:0.74837
# [90]	validation_0-auc:0.92620	validation_1-auc:0.74967
# [91]	validation_0-auc:0.92633	validation_1-auc:0.74967
# [92]	validation_0-auc:0.92646	validation_1-auc:0.74837
# [93]	validation_0-auc:0.92654	validation_1-auc:0.74837
# [94]	validation_0-auc:0.92651	validation_1-auc:0.74837
# [95]	validation_0-auc:0.92675	validation_1-auc:0.74837
# [96]	validation_0-auc:0.92706	validation_1-auc:0.74837
# [97]	validation_0-auc:0.92731	validation_1-auc:0.74837
# [98]	validation_0-auc:0.92734	validation_1-auc:0.75098
# [99]	validation_0-auc:0.92769	validation_1-auc:0.75228
# [100]	validation_0-auc:0.92794	validation_1-auc:0.75228
# [101]	validation_0-auc:0.92831	validation_1-auc:0.75750
# [102]	validation_0-auc:0.92823	validation_1-auc:0.75880
# [103]	validation_0-auc:0.92840	validation_1-auc:0.75750
# ROC AUC: 0.8858

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1,1,figsize=(10, 5))
plot_importance(xgb_clf, ax=ax , max_num_features=20,height=0.4)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
hyper_best_pred = xgb_clf.predict(X_test)
hyper_best_proba = xgb_clf.predict_proba(X_test)[:, 1]

get_clf_eval(y_test , hyper_best_pred, hyper_best_proba)
# Out:
# 오차 행렬
# [[105   5]
#  [ 38  31]]
# 정확도: 0.7598, 정밀도: 0.8611, 재현율: 0.4493,    F1: 0.5905, AUC:0.8858
